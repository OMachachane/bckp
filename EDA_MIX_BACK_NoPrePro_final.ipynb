# %%
import numpy as np
import pandas as pd
# For visualizations
import matplotlib.pyplot as plt
# For regular expressions
import re
# For handling string
import string
# For performing mathematical operations
import math

import swifter
import spacy
import ssl
from spacy import displacy
import pandas as pd
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from sklearn.metrics import accuracy_score
from spacy.matcher import Matcher
from spacy.pipeline import EntityRuler

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from fuzzywuzzy import process, fuzz

from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

import nltk
from nltk.util import ngrams
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
stop=set(stopwords.words('english'))
#nltk.download('stopwords')

from sklearn.linear_model import LogisticRegression

from joblib import Parallel, delayed

from tqdm import tqdm
tqdm.pandas()

import matplotlib.pyplot as plt

import seaborn as sns

import re

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing

from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split

global cls_acc
cls_acc = 0
global cls_time
cls_time = 0
import time
import io

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from IPython.display import display
from IPython.display import display

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

import seaborn as sns
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA - Exploratory Data Anaysis
# - Importing the original dataset
# - Checking the number of rows and columns of the dataset
# - Checking the total of null values per columns
# - Checking the total of unique values per column

# %%
df = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202304040839.csv') # df MIX

pd.set_option('display.max_colwidth', None)
df = df.sample(10000)

#df.head(5)

# %%
#df_unknown.head(3) ===================================

# %%
df.head(6)
# Out:
#         fi_id                         account_id  \
# 43572  DI1534  Ab38d9a72f65d38afbb2b95bf1cca691a
# 3784   DI1425  A1bc042a806eb32668c9ebd171afbf0a7
# 48818  DI1384  Afadfe13cfe5636b085f7657bb578e8eb
# 29107  DI4090  A7b6a794cab6036c1804f1cfa76f364ee
# 35045  DI1385  Af97f68f38fa23fdbb067e9932d4cd3bb
# 30512  DI1141  A9cfe2576263b35bca4a18c640a452866
#
#                           transaction_id  amount currency  \
# 43572  T312b7d75b3063a88a450e7fb09912aed   45.58      USD
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200   24.39      USD
# 48818  Te0b7145f03be3a55b1167d96389ddada  237.47      USD
# 29107  T8febfbd1070c30059ea0150113232244   49.53      USD
# 35045  Tdb48c9dd884c340388c813ede2a3f211    2.20      USD
# 30512  T88237fa296163c17a0744344e8868019  160.90      USD
#
#                          txn_desc1  \
# 43572   Withdrawal BK OF AMER VISA
# 3784        Withdrawal Debit ADORA
# 48818  Withdrawal PECO ENERGY COMP
# 29107            Withdrawal PAYPAL
# 35045        Withdrawal DEBIT CARD
# 30512               ACH Withdrawal
#
#                                                                                                  txn_desc2  \
# 43572  TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                             K-BEAUTY COS ORLANDO FLUS
# 48818               TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                      TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045     AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# 30512                                                                         FST ENERGY OHIO - ONLINE PMT
#
#       region transaction_timestamp  merchant_id    merchant_name  \
# 43572    NaN            2023-02-27      10250.0  BANK OF AMERICA
# 3784     NaN            2022-04-09          NaN  Unknow Merchant
# 48818    NaN            2023-03-20          NaN  Unknow Merchant
# 29107    NaN            2022-09-19          NaN  Unknow Merchant
# 35045    NaN            2022-12-13          NaN  Unknow Merchant
# 30512     MT            2022-12-27          NaN  Unknow Merchant
#
#               payment_agent payment_agent_id extract_date  \
# 43572  Unknow Payment Agent              NaN   2023-03-01
# 3784   Unknow Payment Agent              NaN   2022-04-13
# 48818  Unknow Payment Agent              NaN   2023-03-22
# 29107                PAYPAL            12131   2022-09-24
# 35045  Unknow Payment Agent              NaN   2022-12-17
# 30512  Unknow Payment Agent              NaN   2022-12-30
#
#                                    filename                              name
# 43572  FTS_CSLK_TRANSAC_20230228_100007.csv     Sun East Federal Credit Union
# 3784   FTS_CSLK_TRANSAC_20220412_100001.csv            Fairwinds Credit Union
# 48818  FTS_CSLK_TRANSAC_20230321_100006.csv                  Philadelphia Fcu
# 29107  FTS_CSLK_TRANSAC_20220923_100006.csv   Community Resource Credit Union
# 35045  FTS_CSLK_TRANSAC_20221216_100006.csv                      Kirtland FCU
# 30512  FTS_CSLK_TRANSAC_20221229_100006.csv  SEVEN SEVENTEEN CREDIT UNION INC

# %%
# Concatenating transaction descriptions columns
#df["TRANSACTION_DETAILS"] = df['txn_desc1'].astype(str) +" "+ df['txn_desc2'].astype(str)

# %%
#df_unknown["TRANSACTION_DETAILS"] = df_unknown['txn_desc1'].astype(str) +" %%%%% "+ df_unknown['txn_desc2'].astype(str) ===================================

# %%
#df["LEN_WORDS"] = df["TRANSACTION_DETAILS"].apply(lambda x: len(str(x).split()))

# %%
#df["LEN_WORDS"].describe()

# %%
print('Total number of rows and columns:', df.shape)
# Out:
# Total number of rows and columns: (10000, 16)

# %%
#print('Total number of rows and columns (UNKNOWN):', df_unknown.shape) ===================================

# %%
print('Total number of null values per column:')
df.isnull().sum()
#df.dropna(inplace=True)
# Out:
# Total number of null values per column:
# fi_id                       0
# account_id                  0
# transaction_id              0
# amount                      0
# currency                    0
# txn_desc1                   1
# txn_desc2                1031
# region                   8663
# transaction_timestamp       0
# merchant_id              5131
# merchant_name               0
# payment_agent               0
# payment_agent_id         8953
# extract_date                0
# filename                    0
# name                        0
# dtype: int64

# %%
print('Total number of unique values per column:')
df.nunique()
# Out:
# Total number of unique values per column:
# fi_id                      158
# account_id                9419
# transaction_id           10000
# amount                    5133
# currency                     1
# txn_desc1                 4056
# txn_desc2                 8193
# region                      45
# transaction_timestamp      524
# merchant_id                512
# merchant_name              509
# payment_agent               14
# payment_agent_id            25
# extract_date               504
# filename                   544
# name                       158
# dtype: int64

# %% [markdown]
# # Unknown Merchant Names
# - Selecting dataset with unknown merchants only
# - Checking the number of rows and columns

# %%
# Selecting only known merchants names from the original dataset
#df_unknown_merchs = df_unknown[['transaction_id','TRANSACTION_DETAILS','merchant_name' ]].copy(deep=True) =================================
#df_unknown_merchs = df_unknown_merchs[df["merchant_name"].str.contains("Unknow Merchant") == True]
#print('Total number of rows and columns:', df_unknown_merchs.shape) ===================================

# %%
#df_unknown_merchs ===================================

# %%
#df_unknown_merchs.shape ===================================

# %%
#print('Total number of known merchants:\n',len(df_unknown_merchs.merchant_name.unique())) ===================================

# %%
#print('Total number of occurences per merchant name (UNKNOWN):\n',(df_unknown_merchs.merchant_name).value_counts(normalize=True).mul(100).round(1).astype(str) + '%') ===================================

# %%
# Copy of the afs merchant names column
#df_unknown_merchs['AFS_MECHANT_NAMES'] = df_unknown_merchs['merchant_name'] ===================================
# Droping original cols
#df_unknown_merchs = df_unknown_merchs.drop(['merchant_name'], axis=1) ===================================

# %%
# ===================================
# df_unknown_merchs_pred = df_unknown_merchs.copy(deep=True)
# df_unknown_merchs_pred['AFS_MECHANT_NAMES'] = df_unknown_merchs_pred['AFS_MECHANT_NAMES'].str.lower()
# df_unknown_merchs_pred['TRANSACTION_DETAILS']= df_unknown_merchs_pred['TRANSACTION_DETAILS'].str.lower().str.replace(r'\s{2,}','').str.replace(r"[,;@#?!&$*]+\ *", " ")

# %%
#df_unknown_merchs.head(3) ===================================

# %%
#df_unknown_merchs_pred.head(5) ===================================

# %% [markdown]
# # Known Merchant Names
# - Selecting known merchants only
# - Checking the number of rows/transactions
# - Checking the total number of merchants
# - Checking the total number of occurrences per merchant
# - Concatenated the transaction details columns
# - Defined a function for word cloud for top merchants
# - Defined a function for N-gram for top merchants with combined names
# - Defined a function to check occurence of merchants in transaction columns

# %%
# Selecting only known merchants names from the original dataset
# df_known_merchs = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True) ===================================
df_known_merchs = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True)
#df_known_merchs = df_known_merchs[df["merchant_name"].str.contains("Unknow Merchant") == False] ===================================
#######
# df_known_merchs_cp2 = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True) ===================================
df_known_merchs_cp2 = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True)
#df_known_merchs_cp2 = df_known_merchs_cp2[df["merchant_name"].str.contains("Unknow Merchant") == False] ===================================

#df_known_merchs = df_known_merchs.head(50)

# %%
print('Number of transactions with known merchant names:\n',len(df_known_merchs) )
# Out:
# Number of transactions with known merchant names:
#  10000

# %%
print('Total number of known merchants:\n',len(df_known_merchs.merchant_name.unique()))
# Out:
# Total number of known merchants:
#  509

# %%
#print('Total number of UNknown merchants:\n',len(df_known_merchs.merchant_name.unique())) ===================================
print('Total number of occurences per merchant name:\n',(df_known_merchs.merchant_name).value_counts())
# Out:
# Total number of occurences per merchant name:
#  Unknow Merchant      5138
# AMAZON.COM            405
# WALMART               323
# MCDONALD'S            168
# APPLE STORE           154
#                      ...
# BLIZZARD.COM            1
# CAREMARK PHARMACY       1
# RESIDENCE INN           1
# LEVI STRAUSS            1
# FRONTIER AIRLINES       1
# Name: merchant_name, Length: 509, dtype: int64

# %%
print('Total number of occurences per merchant name:\n',(df_known_merchs.merchant_name).value_counts(normalize=True).mul(100).round(1).astype(str) + '%')
# Out:
# Total number of occurences per merchant name:
#  Unknow Merchant      51.4%
# AMAZON.COM            4.0%
# WALMART               3.2%
# MCDONALD'S            1.7%
# APPLE STORE           1.5%
#                      ...
# BLIZZARD.COM          0.0%
# CAREMARK PHARMACY     0.0%
# RESIDENCE INN         0.0%
# LEVI STRAUSS          0.0%
# FRONTIER AIRLINES     0.0%
# Name: merchant_name, Length: 509, dtype: object

# %%
# Concatenating transaction descriptions columns
#df_known_merchs["TRANSACTION_DETAILS"] = df_known_merchs['txn_desc1'].astype(str) +" "+ df_known_merchs['txn_desc2'].astype(str)
df_known_merchs["TRANSACTION_DETAILS"] = df_known_merchs['txn_desc1'].astype(str) +" "+ df_known_merchs['txn_desc2'].astype(str)

# %%
df_known_merchs.head(5)
# Out:
#                           transaction_id                    txn_desc1  \
# 43572  T312b7d75b3063a88a450e7fb09912aed   Withdrawal BK OF AMER VISA
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200       Withdrawal Debit ADORA
# 48818  Te0b7145f03be3a55b1167d96389ddada  Withdrawal PECO ENERGY COMP
# 29107  T8febfbd1070c30059ea0150113232244            Withdrawal PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211        Withdrawal DEBIT CARD
#
#                                                                                                  txn_desc2  \
# 43572  TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                             K-BEAUTY COS ORLANDO FLUS
# 48818               TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                      TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045     AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
#
#               payment_agent    merchant_name  \
# 43572  Unknow Payment Agent  BANK OF AMERICA
# 3784   Unknow Payment Agent  Unknow Merchant
# 48818  Unknow Payment Agent  Unknow Merchant
# 29107                PAYPAL  Unknow Merchant
# 35045  Unknow Payment Agent  Unknow Merchant
#
#                                                                                                                   TRANSACTION_DETAILS
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814

# %%
df_known_merchs.head(5)
# Out:
#                           transaction_id                    txn_desc1  \
# 43572  T312b7d75b3063a88a450e7fb09912aed   Withdrawal BK OF AMER VISA
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200       Withdrawal Debit ADORA
# 48818  Te0b7145f03be3a55b1167d96389ddada  Withdrawal PECO ENERGY COMP
# 29107  T8febfbd1070c30059ea0150113232244            Withdrawal PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211        Withdrawal DEBIT CARD
#
#                                                                                                  txn_desc2  \
# 43572  TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                             K-BEAUTY COS ORLANDO FLUS
# 48818               TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                      TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045     AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
#
#               payment_agent    merchant_name  \
# 43572  Unknow Payment Agent  BANK OF AMERICA
# 3784   Unknow Payment Agent  Unknow Merchant
# 48818  Unknow Payment Agent  Unknow Merchant
# 29107                PAYPAL  Unknow Merchant
# 35045  Unknow Payment Agent  Unknow Merchant
#
#                                                                                                                   TRANSACTION_DETAILS
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814

# %%
def word_cloud(a):
    # Word cloud for more frequent merchant names
    text = " ".join(i for i in a)
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
    plt.figure( figsize=(7,7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
# # Copy of the afs merchant names column
df_known_merchs['AFS_PAYMENT_AGENTS'] = df_known_merchs['payment_agent'] 
# # Copy of the afs merchant names column
df_known_merchs['AFS_MECHANT_NAMES'] = df_known_merchs['merchant_name']
# # Droping original cols
# df_known_merchs = df_known_merchs.drop(['txn_desc1', 'txn_desc2','payment_agent','merchant_name'], axis=1) ===================================
df_known_merchs = df_known_merchs.drop(['txn_desc1', 'txn_desc2'], axis=1)

# # Word cloud for more frequent merchant names
word_cloud(df_known_merchs.AFS_MECHANT_NAMES)

# %%
#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

# Define a custom color palette
colors = ['#003865', '#FF9230', '#00A9AB']

plt.xticks(rotation=90)
plt.bar(top_categories.index, top_categories.values, align='center', color=colors)

ax2 = plt.twinx()
#ax2.set_ylim([0, 100])
ax2.plot(category_percentages.index, category_percentages.values, color='red', linewidth=2.5)
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences (%)')
plt.title('Top 10 Merchant Names')

plt.show()

# %%
df_known_merchs.head(6)
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
# 30512  T88237fa296163c17a0744344e8868019  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
# 30512  Unknow Merchant
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# 30512                                                                                     ACH Withdrawal FST ENERGY OHIO - ONLINE PMT
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES
# 43572  Unknow Payment Agent   BANK OF AMERICA
# 3784   Unknow Payment Agent   Unknow Merchant
# 48818  Unknow Payment Agent   Unknow Merchant
# 29107                PAYPAL   Unknow Merchant
# 35045  Unknow Payment Agent   Unknow Merchant
# 30512  Unknow Payment Agent   Unknow Merchant

# %%
def get_top_ngram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx])
                  for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:10]

# %%
# top_n_bigrams=get_top_ngram(df_known_merchs['AFS_MECHANT_NAMES'],2)[:10] 
top_n_bigrams=get_top_ngram(df_known_merchs['merchant_name'],2)[:10] 
x,y=map(list,zip(*top_n_bigrams)) 
sns.barplot(x=y,y=x);

# %%
def check_names(merchant, t_details):
    
    # Variations for merchant name column
    merchant_1 = merchant
    merchant_2 = merchant_1.lower()
    merchant_3 = re.sub("[\\\\/:*?'#<>|-]", '', merchant_2)
    merchant_4 = re.sub(' ', '', merchant_2)
    merchant_5 = re.sub('[.com/%]', ' ', merchant_2)
    merch_list = merchant_1.split() + merchant_2.split() + merchant_3.split() + merchant_4.split() + merchant_5.split() + merchant.split()
    
    # Variations for transaction details column
    t_details_1 = t_details
    t_details_2 = t_details.lower()
    t_details_3 = re.sub("[\\\\/:*?'#<>|-]", '', t_details_2)
    t_details_4 = re.sub("[.com/%]", " ",t_details_2)
    t_details_5 = re.sub("[\\\\/:*?'#<>|-]", ' ', t_details_2)
    date_pattern = re.sub("\d{1,2}/\d{1,2}(/\d{2,4})?", "", t_details_2)
    
    # Merchants mentioned in transaction description w/ variations
    comp_1 = re.sub("Prime", "AMAZONVOD",t_details_1)
    comp_2 = re.sub("VZWRLSS", "VERIZON WIRELESS",t_details_1)
    comp_3 = re.sub("WM", "WALMART",t_details_1)

    
    # Creating a list of conversions to check if merchants are mentioned in transation descriotions 
    details_lis = t_details_2.split()
    details_lis_1 = t_details_1.split() + t_details_2.split() + t_details_3.split() + details_lis + t_details_4.split() + t_details_5.split() + comp_1.split() + comp_2.split() + comp_3.split() + t_details.split() + date_pattern.split()
    
    # Conditions to check if words are in transaction strings
    if (merchant in t_details_3 or t_details_3 in merchant or           
        (merchant_2 in t_details_3 or t_details_3 in merchant_2) or 
        (merchant_3 in t_details_3 or t_details_3 in merchant_3) or
        (merchant_4 in t_details_3 or t_details_3 in merchant_4) or
        (merchant_1 in t_details_3 or t_details_1 in merchant_4) or
        (merchant_1 in details_lis_1 or merchant_4 in details_lis)or
        (any(item in merch_list for item in details_lis_1)) or
        (merchant_1[:4] in t_details_1)):
        return True
    else:
        return False

# %% [markdown]
# - Checked the occurrence of merchants in the first and secod transation colums separately
# - Checked the total number of occurrences per column

# %%
# # Merchants in the txt_1 or txt_2 columns
# df_known_merchs_cp2['txn_desc2'] = df_known_merchs_cp2['txn_desc2'].astype(str)
# df_known_merchs_cp2['txn_desc1'] = df_known_merchs_cp2['txn_desc1'].astype(str)
# df_known_merchs_cp2['merchant_name'] = df_known_merchs_cp2['merchant_name'].astype(str)
# df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] = df_known_merchs_cp2.apply(lambda x: check_names(x.merchant_name, x.txn_desc1), axis=1) # OR txn_desc2
df_known_merchs_cp2.head(5)
# Out:
#                           transaction_id                    txn_desc1  \
# 43572  T312b7d75b3063a88a450e7fb09912aed   Withdrawal BK OF AMER VISA
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200       Withdrawal Debit ADORA
# 48818  Te0b7145f03be3a55b1167d96389ddada  Withdrawal PECO ENERGY COMP
# 29107  T8febfbd1070c30059ea0150113232244            Withdrawal PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211        Withdrawal DEBIT CARD
#
#                                                                                                  txn_desc2  \
# 43572  TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                             K-BEAUTY COS ORLANDO FLUS
# 48818               TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                      TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045     AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
#
#               payment_agent    merchant_name
# 43572  Unknow Payment Agent  BANK OF AMERICA
# 3784   Unknow Payment Agent  Unknow Merchant
# 48818  Unknow Payment Agent  Unknow Merchant
# 29107                PAYPAL  Unknow Merchant
# 35045  Unknow Payment Agent  Unknow Merchant

# %%
print('Total of transactions with known merchants:\n',len(df_known_merchs_cp2))
# Out:
# Total of transactions with known merchants:
#  10000

# %%
#print('Merchant name occurrence in txn_desc1 column:\n',(df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] == True).sum())

# %%
#df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] = df_known_merchs_cp2.apply(lambda x: check_names(x.merchant_name, x.txn_desc2), axis=1)
#print('Merchant name occurrence in txn_desc2 column:\n',(df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] == True).sum())

# %% [markdown]
# - Checked occurrence of merchants in concatenated transaction column
# - Created CHECK_MERCH_TRA to inspect occurrences
# - Checked total number of occurences in merchant details coolumn

# %%
# Checking if merchant names are mentioned in the transaction description
df_known_merchs['CHECK_MERCH_TRA'] = df_known_merchs.apply(lambda x: check_names(x.AFS_MECHANT_NAMES, x.TRANSACTION_DETAILS), axis=1)

df_known_merchs.head(5)
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True

# %%
# Merchant name in the transaction description
#print('Merchant name in the transaction description:\n',(df_known_merchs['CHECK_MERCH_TRA'] == True).sum() )

# %% [markdown]
# - Created a copy to encode CHECK_MERCH_TRA results
# - Created a chart to compare the results
# - Created a word cloud of AFS_MECHANT_NAMES to get most frequen merchants
# - Checked how many times merchants are mentioned in transaction details
# - Checked how many times merchants are not in transaction details
# - Created word cloud for merchants not in transaction details

# %%
df_known_merchs_cp = df_known_merchs[['transaction_id','TRANSACTION_DETAILS','AFS_PAYMENT_AGENTS','AFS_MECHANT_NAMES','CHECK_MERCH_TRA']].copy(deep=True)

#df_known_merchs_cp = df_known_merchs[['transaction_id','TRANSACTION_DETAILS','merchant_name']].copy(deep=True)
df_known_merchs_cp.head()
# Out:
#                           transaction_id  \
# 43572  T312b7d75b3063a88a450e7fb09912aed
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200
# 48818  Te0b7145f03be3a55b1167d96389ddada
# 29107  T8febfbd1070c30059ea0150113232244
# 35045  Tdb48c9dd884c340388c813ede2a3f211
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(x="CHECK_MERCH_TRA", data=df_known_merchs_cp)
plt.title("Merchant Names in Transaction Details")

total = len(df_known_merchs_cp["CHECK_MERCH_TRA"])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() + 0.1
    y = p.get_y() + p.get_height()/2

ax2 = ax.twinx()
ax2.set_ylim([0, 100])
ax2.set_ylabel('Number of occurrences (%)')

plt.show()

# %%
#print('Percentage of merchant names in T details or not (1/0):\n',(df_known_merchs_cp.CHECK_MERCH_TRA).value_counts(normalize=True).mul(100).round(1).astype(str) + '%');

# %%
# # Number of merchant names in transaction details
# df_check_true = pd.DataFrame()
# df_check_true = df_known_merchs.loc[df_known_merchs['CHECK_MERCH_TRA'] == True]
# print('Number of merchant names in transaction details:\n',len(df_check_true))

# %%
# Word cloud for more frequent merchant names WHEN merchant name is in transaction description

# word_cloud(df_check_true.AFS_MECHANT_NAMES)

# %%
# print('Total number of occurences per merchant name:\n',(df_check_true.AFS_MECHANT_NAMES).value_counts(normalize=True).mul(100).round(1).astype(str) + '%')

# %%
# print('Number of merchant names NOT in the transaction description:\n',(df_known_merchs['CHECK_MERCH_TRA'] == False).sum())

# %%
# # Number of merchant names not in transaction details
# df_check_false = pd.DataFrame()
# df_check_false = df_known_merchs.loc[df_known_merchs['CHECK_MERCH_TRA'] == False]
# #print('Number of merchant names NOT in the transaction description:\n', len(df_check_false))

# %%
# # Word cloud for more frequent merchant names WHEN merchant name is NOT in transaction description
# word_cloud(df_check_false.AFS_MECHANT_NAMES)

# %%
#print('Total number of occurences per merchant name WHEN merchant name is NOT in transation details:\n', (df_check_false.AFS_MECHANT_NAMES).value_counts(normalize=True).mul(100).round(1).astype(str) + '%')

# %% [markdown]
# - Merchant names not mentioned in transaction description

# %%
# # Merchant names not mentioned in transaction description
# df_known_merchs.loc[df_known_merchs['CHECK_MERCH_TRA']==False]

# %% [markdown]
# # Payment Agents VS Merchant Names
# - Selected known payment agents
# - Checked number of total occurences per agents
# - Checked total number of payment agents
# - Checked number of transactions with known payment agents
# - Defined a function compare payment agents with merchant names
# - Created CHECK_MERCH_AGTS to check when agents and merchants are same
# - Checked Totals for different situations

# %%
df_known_payment_agents = df_known_merchs.copy(deep=True)
# # Known payment agent names
df_known_payment_agents = df_known_payment_agents.loc[df_known_payment_agents['AFS_PAYMENT_AGENTS'] != 'Unknow Payment Agent']
df_known_payment_agents
# Out:
#                           transaction_id    payment_agent    merchant_name  \
# 29107  T8febfbd1070c30059ea0150113232244           PAYPAL  Unknow Merchant
# 13091  T1fc6253c450b3e748b669ffd52d72ad1  SQUARE CASH APP  Unknow Merchant
# 15079  T27c6f0583cd43cfebe479b24c83ec9c4  SQUARE CASH APP  Unknow Merchant
# 34735  T57c1291847163c319e153e84f616f3f0           PAYPAL  Unknow Merchant
# 49751  Te0482b68dfb73d40a3d80fe17892759b            VENMO  Unknow Merchant
# ...                                  ...              ...              ...
# 43633  Tdd64011b291d3533961a7acb3dc57820  SQUARE CASH APP  Unknow Merchant
# 49047  T3a49949ef0893183bfefbd1b4fdb31f3           PAYPAL  Unknow Merchant
# 4359   T9d97128f2efb371c87c676e8ffa34d43           PAYPAL  Unknow Merchant
# 10727  T3e471be44af4348cb1beb76ef7a43c28           GOOGLE           GOOGLE
# 11449  Tfcb651d7fe09360780e3c6f031bed592  SQUARE CASH APP  Unknow Merchant
#
#                                                                              TRANSACTION_DETAILS  \
# 29107          Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 13091                                                          POS CASH APP*RENY REN*A*4551 CAUS
# 15079  Withdrawal MasterCard DC CASH APP*NATHAN 1455 MARKET ST *3176 Date 08/23/22 8 *820 3 4829
# 34735                                    External Withdrawal PAYPAL INSTANT TRANSFER - INST XFER
# 49751     Withdrawal CONSUMER DEBIT VENMO *4430 NY Date 07/21/22 0 *3660 0 4829 %% Card 18 #1695
# ...                                                                                          ...
# 43633                                                 DDA PUR CASH APP*R CASH APP*R L *3176 CA *
# 49047                                                   ELECTRONIC WITHDRAWAL PAYPAL INST XFER *
# 4359                                                  EXT WD PAYPAL INSTANT TRANSFER - INST XFER
# 10727                                    DDA PUR GOOGLE *Su GOOGLE *Supercel Mountain View CA **
# 11449                                                    Purchase CASH APP*DIEDREA LO *4551 CAUS
#
#       AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 29107             PAYPAL   Unknow Merchant            False
# 13091    SQUARE CASH APP   Unknow Merchant            False
# 15079    SQUARE CASH APP   Unknow Merchant            False
# 34735             PAYPAL   Unknow Merchant            False
# 49751              VENMO   Unknow Merchant             True
# ...                  ...               ...              ...
# 43633    SQUARE CASH APP   Unknow Merchant            False
# 49047             PAYPAL   Unknow Merchant            False
# 4359              PAYPAL   Unknow Merchant            False
# 10727             GOOGLE            GOOGLE             True
# 11449    SQUARE CASH APP   Unknow Merchant            False
#
# [916 rows x 7 columns]

# %%
print('Number of total occurences per payment agents:\n', (df_known_payment_agents.AFS_PAYMENT_AGENTS).value_counts(normalize=True).mul(100).round(1).astype(str) + '%')
# Out:
# Number of total occurences per payment agents:
#  PAYPAL             29.7%
# SQUARE CASH APP    20.2%
# SQUARE             17.6%
# VENMO              13.2%
# GOOGLE              7.2%
# DOORDASH            6.3%
# APPLE CASH          1.9%
# ROKU                1.5%
# FACEBOOK            0.8%
# GRUBHUB.COM         0.5%
# LEVELUP             0.5%
# INSTACART           0.4%
# OLO                 0.1%
# Name: AFS_PAYMENT_AGENTS, dtype: object

# %%
print('Total number of payment agents:\n',len(df_known_payment_agents.AFS_PAYMENT_AGENTS.unique()))
# Out:
# Total number of payment agents:
#  13

# %%
print('Number of transactions with known payment agents:\n',len(df_known_payment_agents))
# Out:
# Number of transactions with known payment agents:
#  916

# %%
# Function to compare payment agent names with merchant names
def compare_occurences(agent, merchant):
    agent = agent.split()
    merchant = merchant.split()
    # Conditions to check if words are in transaction strings
    if (merchant in agent or agent in merchant or
        (any(item in merchant for item in agent)) or
        (merchant[:3] in agent)):
        return True
    else:
        return False

# %%
# # Checking if merchant names and payment agents are same
df_known_payment_agents['CHECK_MERCH_AGTS'] = df_known_payment_agents.apply(lambda x: compare_occurences(x.AFS_MECHANT_NAMES, x.AFS_PAYMENT_AGENTS), axis=1)
# df_known_payment_agents.head()

# %% [markdown]
# - Checked how many times merchant names and payment agents are same
# - Checked how many time merchant names and payment agents are different
# - Checked total number of transactions with known agents

# %%
print('Same merchant names and payment agents:\n',len(df_known_payment_agents.loc[df_known_payment_agents['CHECK_MERCH_AGTS']==True]))
# Out:
# Same merchant names and payment agents:
#  91

# %%
print('Merchant names and payment agents are diferent:\n',len(df_known_payment_agents.loc[df_known_payment_agents['CHECK_MERCH_AGTS']==False]))
# Out:
# Merchant names and payment agents are diferent:
#  825

# %%
print('Number of rows with known Agents:\n',len(df_known_payment_agents))
# Out:
# Number of rows with known Agents:
#  916

# %%
df_known_payment_agents
# Out:
#                           transaction_id    payment_agent    merchant_name  \
# 29107  T8febfbd1070c30059ea0150113232244           PAYPAL  Unknow Merchant
# 13091  T1fc6253c450b3e748b669ffd52d72ad1  SQUARE CASH APP  Unknow Merchant
# 15079  T27c6f0583cd43cfebe479b24c83ec9c4  SQUARE CASH APP  Unknow Merchant
# 34735  T57c1291847163c319e153e84f616f3f0           PAYPAL  Unknow Merchant
# 49751  Te0482b68dfb73d40a3d80fe17892759b            VENMO  Unknow Merchant
# ...                                  ...              ...              ...
# 43633  Tdd64011b291d3533961a7acb3dc57820  SQUARE CASH APP  Unknow Merchant
# 49047  T3a49949ef0893183bfefbd1b4fdb31f3           PAYPAL  Unknow Merchant
# 4359   T9d97128f2efb371c87c676e8ffa34d43           PAYPAL  Unknow Merchant
# 10727  T3e471be44af4348cb1beb76ef7a43c28           GOOGLE           GOOGLE
# 11449  Tfcb651d7fe09360780e3c6f031bed592  SQUARE CASH APP  Unknow Merchant
#
#                                                                              TRANSACTION_DETAILS  \
# 29107          Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 13091                                                          POS CASH APP*RENY REN*A*4551 CAUS
# 15079  Withdrawal MasterCard DC CASH APP*NATHAN 1455 MARKET ST *3176 Date 08/23/22 8 *820 3 4829
# 34735                                    External Withdrawal PAYPAL INSTANT TRANSFER - INST XFER
# 49751     Withdrawal CONSUMER DEBIT VENMO *4430 NY Date 07/21/22 0 *3660 0 4829 %% Card 18 #1695
# ...                                                                                          ...
# 43633                                                 DDA PUR CASH APP*R CASH APP*R L *3176 CA *
# 49047                                                   ELECTRONIC WITHDRAWAL PAYPAL INST XFER *
# 4359                                                  EXT WD PAYPAL INSTANT TRANSFER - INST XFER
# 10727                                    DDA PUR GOOGLE *Su GOOGLE *Supercel Mountain View CA **
# 11449                                                    Purchase CASH APP*DIEDREA LO *4551 CAUS
#
#       AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA  CHECK_MERCH_AGTS
# 29107             PAYPAL   Unknow Merchant            False             False
# 13091    SQUARE CASH APP   Unknow Merchant            False             False
# 15079    SQUARE CASH APP   Unknow Merchant            False             False
# 34735             PAYPAL   Unknow Merchant            False             False
# 49751              VENMO   Unknow Merchant             True             False
# ...                  ...               ...              ...               ...
# 43633    SQUARE CASH APP   Unknow Merchant            False             False
# 49047             PAYPAL   Unknow Merchant            False             False
# 4359              PAYPAL   Unknow Merchant            False             False
# 10727             GOOGLE            GOOGLE             True              True
# 11449    SQUARE CASH APP   Unknow Merchant            False             False
#
# [916 rows x 8 columns]

# %% [markdown]
# # Named Entity Recognition
# - Created a copy of df_known_merchs for predictions purposes - "df_known_merchs_pred"
# - Created the PREDICTIONS column
# - Used NER from Spacy
# - Applied Entity Ruler to add all the merchants (PATTERNS) from AFS into the model
# - Defined function to find patterns from AFS predictions - "def_patterns"
# - Defined function to find the organisations in the Transaction details column - "find_org"
# - Defined funtion to implement parallel processing = "find_org_parallel"
# - Implemented cust NER model and displayed the results

# %%
df_known_merchs_pred = df_known_merchs.copy(deep=True)
#df_known_merchs_pred['AFS_MECHANT_NAMES'] = df_known_merchs_pred['AFS_MECHANT_NAMES'].str.lower()
#df_known_merchs_pred['TRANSACTION_DETAILS']= df_known_merchs_pred['TRANSACTION_DETAILS'].str.lower().str.replace(r'\s{2,}','').str.replace(r"[,;@#?!&$*]+\ *", " ")

# %%
df_known_merchs_pred.head(10)
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
# 30512  T88237fa296163c17a0744344e8868019  Unknow Payment Agent
# 34215  T3b526c9707ff3b53911496f14f016335  Unknow Payment Agent
# 13091  T1fc6253c450b3e748b669ffd52d72ad1       SQUARE CASH APP
# 32092  T2eb7e45137d9311aab8b603cfddbd203  Unknow Payment Agent
# 10946  T8e96bd19725038ec81e4f11d2bf5b273  Unknow Payment Agent
#
#                    merchant_name  \
# 43572            BANK OF AMERICA
# 3784             Unknow Merchant
# 48818            Unknow Merchant
# 29107            Unknow Merchant
# 35045            Unknow Merchant
# 30512            Unknow Merchant
# 34215            Unknow Merchant
# 13091            Unknow Merchant
# 32092                    WALMART
# 10946  CHEDDAR'S SCRATCH KITCHEN
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# 30512                                                                                     ACH Withdrawal FST ENERGY OHIO - ONLINE PMT
# 34215                                                                  DEBIT CARD DEBIT 02-27-2023 LEAFFILTER GUTTE 330-655-7950 OH *
# 13091                                                                                               POS CASH APP*RENY REN*A*4551 CAUS
# 32092                                                                   CKCD DEBIT 4245 02/06 15:56 WAL-MART # 2645 BLACKSTONE VA nan
# 10946                                                                   Withdrawal Debit Card Withdrawal CHEDDARS **9 FAYETTEVILLE NC
#
#          AFS_PAYMENT_AGENTS          AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent            BANK OF AMERICA             True
# 3784   Unknow Payment Agent            Unknow Merchant            False
# 48818  Unknow Payment Agent            Unknow Merchant            False
# 29107                PAYPAL            Unknow Merchant            False
# 35045  Unknow Payment Agent            Unknow Merchant             True
# 30512  Unknow Payment Agent            Unknow Merchant            False
# 34215  Unknow Payment Agent            Unknow Merchant            False
# 13091       SQUARE CASH APP            Unknow Merchant            False
# 32092  Unknow Payment Agent                    WALMART             True
# 10946  Unknow Payment Agent  CHEDDAR'S SCRATCH KITCHEN             True

# %% [markdown]
# - Function to find and create a list of patterns

# %%
def def_patterns(a):

    #Creating a list of patterns - with all the merchant names (with and without spaces, quotes, .com, etc.)

    org =  a #df_known_payment_agents['AFS_MECHANT_NAMES']

    #List of Entities and Patterns
    org_list = org.tolist()

    a = [ x.strip() for x in org_list] # list comprehension - all merchant names from original org_list
    a_space =list(filter(lambda x: ' ' in x, a)) # filtering all names w spaces
    a_nospace = [x.replace(' ', '') for x in a_space] # replacing spaces w ''

    a_quo =list(filter(lambda x: "'" in x, a)) # filtering all names w quotes
    a_noquuo = [x.replace("'", '') for x in a_quo] # replacing quotes w ''

    a_com =list(filter(lambda x: '.com' in x, a)) # filtering all names w .com
    a_nocom = [x.replace('.com', '') for x in a_com] # replacing .com w ''

    a_dash =list(filter(lambda x: '-' in x, a)) # filtering all names w dash
    a_nodash = [x.replace('-', '') for x in a_com] # replacing dash w ''

    new_lis = a + a_nospace + a_nocom + a_noquuo + a_nodash # add instead of dis_list


    # Creating a list of patterns with all the variations from new_lis
    patterns = []
    i = 0
    new_lis = tuple(new_lis)
    for item in new_lis:
        patterns.append({"label": 'ORG', "pattern": [{"LOWER":item}]})
        # patterns.append({"label": 'ORG', "pattern": new_lis[i]})
        i+=1

    return patterns

# %%
#patterns = def_patterns(df_known_merchs_pred['AFS_MECHANT_NAMES'])

# %% [markdown]
# - Function to find organisations using patterns

# %%
# Function to find merchant names in a string - using an NER model with the previously created patterns

def find_org(text:str):
    
    #Build upon the spaCy Model
    NER2 = spacy.load("en_core_web_sm")
    
    #Create the EntityRuler
    ruler = NER2.add_pipe("entity_ruler", config={'validate': True})
     
    ruler.add_patterns(patterns)
    doc_ner = NER2(text)
    
    # useless strings
    junk = ['fip', 'ca(2810','fis','xx4386', '#185','*','hr0d','k50ms3hv','xx9510','xx4710','xx4706','xx0322','he34i8pz0','xx3840','pd1387','ma(9661','ns4qa9xb3 ']
    
    #extract entities
    orgs = []
    for ent in doc_ner.ents:
        if ((ent.label_ == "ORG") and (ent.text not in junk)):
            orgs.append(ent.text)
    orgs = list(set(orgs))
    return ' '.join(orgs) if orgs else 'NA'

# %% [markdown]
# - Function for parallel processing

# %%
def find_org_parallel(a:dict):
    i=a.copy()
    print(i)
    result = find_org(i['TRANSACTION_DETAILS'])
    i['PREDICTIONS']= result
    print(i)
    return i

# %%
df_known_merchs_pred.head(5)
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True

# %%
#t_list = df_known_merchs_pred[['transaction_id', 'TRANSACTION_DETAILS', 'AFS_MECHANT_NAMES', 'CHECK_MERCH_TRA']].copy(deep=True).to_dict(orient='records') #replace similarity w unique ID

# %%
# df_known_merchs_pred['PREDICTIONS'] = df_known_merchs_pred.TRANSACTION_DETAILS.swifter.apply(find_org)

# %%
#par = Parallel(n_jobs=-1)(delayed(find_org_parallel)(i) for i in tqdm(t_list))

# %%
#df_known_merchs_pred = pd.DataFrame(par)

# %%
df_known_merchs_pred
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
# ...                                  ...                   ...
# 26983  Tf070625722b2312db91de41c22512d87  Unknow Payment Agent
# 9990   Tc8fb82b314543899a9d64e32a0a139c3  Unknow Payment Agent
# 29047  T20c7cd2c7d8131b880812a479917bd11  Unknow Payment Agent
# 48040  T6aa07c6d49883bbbbbec4a95e0570006  Unknow Payment Agent
# 40415  Tc5ee06b2ba413381aedda0c62e4c3b64  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
# ...                ...
# 26983         AUTOZONE
# 9990   Unknow Merchant
# 29047  Unknow Merchant
# 48040       MURPHY USA
# 40415        WALGREENS
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# ...                                                                                                                               ...
# 26983                                                               DEBIT CARD DEBIT auth #* 07-24-2022 AUTOZONE 0187 3 COLUMBUS GA *
# 9990                                                                                       POS PURCHASE * HOTELBOOKINGSE *9059 UT nan
# 29047                                           MISCELLANEOUS DEBIT ATM 0301 1819 * 3233 N COLE RD BOISE ID ATM TRANSACTION FEE $0.50
# 48040                                                            POS PURCHASE MURPHY7754ATWAL BOSSIER CITY LA * *****1766 01/13 10:40
# 40415                                                                       DEBIT CARD DEBIT 03-29-2023 WALGREENS STORE MISSOULA MT *
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True
# ...                     ...               ...              ...
# 26983  Unknow Payment Agent          AUTOZONE             True
# 9990   Unknow Payment Agent   Unknow Merchant            False
# 29047  Unknow Payment Agent   Unknow Merchant            False
# 48040  Unknow Payment Agent        MURPHY USA             True
# 40415  Unknow Payment Agent         WALGREENS             True
#
# [10000 rows x 7 columns]

# %% [markdown]
# - Function to compare results - True/False

# %%
def check_names_pred(a, b):
    if ((a in b) or (b in a)):
        return True
    elif (fuzz.ratio(a, b) > 92):
        return True
    else:
        return False

# %% [markdown]
# - NER predictions using Spacy and Entity Ruler technique

# %%
def check_names_pred_2(a, b):
    
    # Variations for merchant name column
    merchant_1 = a
    merchant_2 = merchant_1.lower()
    merchant_3 = re.sub("[\\\\/:*?'#<>|-]", '', merchant_2)
    merchant_4 = re.sub(' ', '', merchant_2)
    merchant_5 = re.sub('[.com/]', ' ', merchant_2)
    date_pattern_1 = re.sub("\d{1,2}/\d{1,2}(/\d{2,4})?", "", merchant_2)
    merch_list = merchant_1.split() + merchant_2.split() + merchant_3.split() + merchant_4.split() + merchant_5.split() + a.split() + date_pattern_1.split()     #merch_list =  a.split()
    
    # Variations for transaction details column
    t_details_1 = b
    t_details_2 = b.lower()
    t_details_3 = re.sub("[\\\\/:*?'#<>|-]", '', t_details_2)
    t_details_4 = re.sub("[.com/]", " ",t_details_2)
    t_details_5 = re.sub("[\\\\/:*?'#<>|-]", ' ', t_details_2)
    date_pattern = re.sub("\d{1,2}/\d{1,2}(/\d{2,4})?", "", t_details_2)
    
    # Merchants mentioned in transaction description w/ variations
    comp_1 = re.sub("Prime", "AMAZONVOD",t_details_1)
    comp_2 = re.sub("VZWRLSS", "VERIZON WIRELESS",t_details_1)
    comp_3 = re.sub("WM", "WALMART",t_details_1)
   
    
    # Creating a list of conversions to check if merchants are mentioned in transation descriotions 
    #details_lis = t_details_2.split()
    details_lis_1 = t_details_1.split() + t_details_2.split() + t_details_3.split() + t_details_4.split() + t_details_5.split() + comp_1.split() + comp_2.split() + comp_3.split() + b.split() + date_pattern.split()
    #details_lis_1 = b.split() + date_pattern.split()
    
    
    # Conditions to check if words are in transaction strings
    if (a in b or t_details_3 in a or 
        (merchant_2 in t_details_3 or t_details_3 in merchant_2) or
        (merchant_4 in t_details_3 or t_details_3 in merchant_4) or
        (any(item in merch_list for item in details_lis_1)) or
        (any(item in details_lis_1 for item in merch_list)) or
        (merchant_1[:3] in t_details_1)):
        b=a
        return b #True
    elif ((fuzz.ratio(a, b) > 90) or 
          (fuzz.partial_ratio(a , b) > 90) or 
          (fuzz.token_sort_ratio(a,b) > 90)):
        b=a
        return b #True
    else:
        b = 'nothing'
        return b #False

# %%
# df_known_merchs_pred['CHECK_TF'] = df_known_merchs_pred.apply(lambda x: check_names(x.AFS_MECHANT_NAMES, x.PREDICTIONS), axis=1)
# df_known_merchs_pred.head(10)

# %%
# (df_known_merchs_pred.CHECK_TF).value_counts()

# %%
# df_known_merchs_pred['CHECK_TF_2'] = df_known_merchs_pred.apply(lambda x: check_names_pred_2(x.AFS_MECHANT_NAMES, x.PREDICTIONS), axis=1)
# df_known_merchs_pred.head(10)

# %%
#df_known_merchs_pred = df_known_merchs_pred.sample(450)

# %%
# predicted_labels = df_known_merchs_pred['CHECK_TF_2']
# true_labels = df_known_merchs_pred['AFS_MECHANT_NAMES']
# print(metrics.classification_report(true_labels, predicted_labels))

# %%
# (df_known_merchs_pred.CHECK_TF_2).value_counts()

# %%
def c_matrix(a_pred, a_test):

    # count the number of occurrences of each predicted label
    value_counts = Counter(a_pred)

    # sort the labels by descending order of count
    sorted_labels = sorted(value_counts, key=value_counts.get, reverse=True)

    # print the top 10 labels by count
    for label in sorted_labels[:10]:
        print(f"{label}: {value_counts[label]}")
    

    # get the indices of the top 10 predicted values
    top_10_labels = sorted_labels[:10]

    # filter the true and predicted labels to only include the top 10 labels
    top_10_true = [label if label in top_10_labels else "Other" for label in a_test]
    top_10_pred = [label if label in top_10_labels else "Other" for label in a_pred]

    # create the confusion matrix
    cm = confusion_matrix(top_10_true, top_10_pred,normalize='true')
    

    # plot the confusion matrix
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(cm, annot=True, cmap="Blues", fmt=".2f", xticklabels=top_10_labels + ["Other"], yticklabels=top_10_labels + ["Other"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

    
    return

# %%
# c_matrix(predicted_labels, true_labels)

# %%
# fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 5))
# df_known_merchs_pred.groupby('CHECK_TF').size().plot(kind='pie', autopct='%.2f', title='Accuracy Percentage', explode=[0.05, 0.05], legend=True, shadow=True)
# ax1.set_ylabel('', size=10);

# %%
# (df_known_merchs_pred.CHECK_TF).value_counts()

# %% [markdown]
# # ML Models - Labelling
# - Created different classification models for labelling
#     - Multinomial Naive Bayes
#     - Linear SVC
#     - K-Nearest Neighbors

# %%
df_known_class_pred = df_known_merchs[['transaction_id','TRANSACTION_DETAILS','merchant_name']].copy(deep=True)
# df_known_class_pred['AFS_MECHANT_NAMES'] = df_known_class_pred['AFS_MECHANT_NAMES'].str.lower()
# df_known_class_pred['TRANSACTION_DETAILS']= df_known_class_pred['TRANSACTION_DETAILS'].str.lower().str.replace(r'\s{2,}','').str.replace(r"[,;@#?!&$*]+\ *", " ")
df_known_class_pred = df_known_merchs.copy(deep=True)

# %%
df_known_class_pred.head(6)
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
# 30512  T88237fa296163c17a0744344e8868019  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
# 30512  Unknow Merchant
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# 30512                                                                                     ACH Withdrawal FST ENERGY OHIO - ONLINE PMT
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True
# 30512  Unknow Payment Agent   Unknow Merchant            False

# %%
def top_hists(t_pred, t_test):
    
    # count the number of occurrences of each predicted label
    value_counts = Counter(t_pred)

    # sort the labels by descending order of count
    sorted_labels = sorted(value_counts, key=value_counts.get, reverse=True)

    # get the top 10 labels and their counts
    top_10_labels = sorted_labels[:10]
    top_10_counts = [value_counts[label] for label in top_10_labels]

    # create the horizontal bar plot
    plt.figure(figsize=(6,6))
    sns.barplot(x=top_10_counts, y=top_10_labels, orient='h')
    plt.title('Histogram of Top 10 Labels')
    plt.xlabel('Count')
    plt.ylabel('Label')
    plt.show()
    
    #=========================================================================================
    

    # count the number of occurrences of each predicted label
    value_counts = Counter(t_pred)

    # sort the labels by descending order of count
    sorted_labels = sorted(value_counts, key=value_counts.get, reverse=True)

    # get the top 10 predicted labels and their counts
    top_10_labels = sorted_labels[:10]
    top_10_counts = [value_counts[label] for label in top_10_labels]

    # create a horizontal bar plot for the top 10 predicted labels
    plt.figure(figsize=(6,6))
    plt.barh(range(len(top_10_labels)), top_10_counts, align='center')
    plt.yticks(range(len(top_10_labels)), top_10_labels)
    plt.xlabel('Count')
    plt.ylabel('Predicted Label')
    plt.title('Top 10 Predicted Labels')
    plt.show()
    
    #=========================================================================================
    

    # count the number of occurrences of each predicted label
    value_counts = Counter(t_pred)

    # sort the labels by ascending order of count
    sorted_labels = sorted(value_counts, key=value_counts.get, reverse=False)

    # get the least 10 predicted labels and their counts
    least_10_labels = sorted_labels[:10]
    least_10_counts = [value_counts[label] for label in least_10_labels]

    # create a horizontal bar plot for the least 10 predicted labels
    plt.figure(figsize=(6,6))
    plt.barh(range(len(least_10_labels)), least_10_counts, align='center')
    plt.yticks(range(len(least_10_labels)), least_10_labels)
    plt.xlabel('Count')
    plt.ylabel('Predicted Label')
    plt.title('Least 10 Predicted Labels')
    plt.show()

    return

# %%
def df_description(clss, a_test,a_pred,a_train,b_train,b_test, ccc):     
    #(classifier, y_test, y_pred, y_train,X_train,X_test)
    
    print('Accuracy : {0:0.3f}'.format(accuracy_score(a_test, a_pred)))
    
    #========================================================================================================================
    
    
    print('Number of unique merchants in the test set: ', len(a_test.unique()))
    print('Number of unique merchants in the predicted set: ', len(np.unique(a_pred)))
    print('Number of unique merchants in train set: ', len(a_train.unique()))
    print('Number of unique merchants in OVERS train set: ', len(ccc.unique()))
    print('\nNumber of unique "Transaction Details" rows in test set: ', len(b_train.unique()))
    print('Number of unique "Transaction Details" rows in train set: ', len(b_test.unique()))
    print('\nTotal number of rows in the train set: ', len(b_train))
    print('Total number of rows in the test set', len(b_test))
    
    
    train_acc = accuracy_score(a_train, clss.predict(b_train))
    test_acc = accuracy_score(a_test, a_pred)
    print("Train accuracy:", train_acc)
    print("Test accuracy:", test_acc)
    
    
    #========================================================================================================================
    
    
    # Get the classification report as a string
    report_dict = metrics.classification_report(a_test, a_pred, zero_division=0, output_dict=True)

    # Convert the report dictionary to a pandas dataframe
    report_data = pd.DataFrame(report_dict).transpose()
    
    precision_count = (report_data['precision'] == 1).sum()
    total_categories = report_data.shape[0]
    precision_percentage = precision_count / total_categories * 100
    
    print('\n===================================\n')
    print('Percentage of best precision', precision_percentage)
    
    recall_count = (report_data['recall'] == 1).sum()
    total_categories = report_data.shape[0]
    recall_percentage = recall_count / total_categories * 100
    print('===================================\n')
    print('Percentage of best recall', recall_percentage)
    
    f1score_count = (report_data['f1-score'] == 1).sum()
    total_categories = report_data.shape[0]
    f1score_percentage = f1score_count / total_categories * 100
    print('===================================\n')
    print('Percentage of best f1score', f1score_percentage)
    
    print('===================================\n')
    
    
    top_hists(a_pred, a_test)
    c_matrix(a_pred, a_test)
    
    return

# %%
def c_matrix(a_pred, a_test):

    # count the number of occurrences of each predicted label
    value_counts = Counter(a_pred)

    # sort the labels by descending order of count
    sorted_labels = sorted(value_counts, key=value_counts.get, reverse=True)

    # print the top 10 labels by count
    for label in sorted_labels[:10]:
        print(f"{label}: {value_counts[label]}")
    

    # get the indices of the top 10 predicted values
    top_10_labels = sorted_labels[:10]

    # filter the true and predicted labels to only include the top 10 labels
    top_10_true = [label if label in top_10_labels else "Other" for label in a_test]
    top_10_pred = [label if label in top_10_labels else "Other" for label in a_pred]

    # create the confusion matrix
    cm = confusion_matrix(top_10_true, top_10_pred, normalize='true')

    # plot the confusion matrix
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(cm, annot=True, cmap="Blues", fmt=".2f", xticklabels=top_10_labels + ["Other"], yticklabels=top_10_labels + ["Other"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()
    
    
    return cm

# %%
def l_curve(clss, xt, yt):
    #classifier, X_train_oversampled,y_train_oversampled
    
    train_sizes, train_scores, test_scores = learning_curve(
        clss, xt, yt, cv=5, scoring='f1_macro', 
        train_sizes=np.linspace(0.1, 1.0, 10), shuffle=True, random_state=99
    )

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.figure()
    plt.title("Learning Curve")
    plt.xlabel("Training Examples")
    plt.ylabel("Score")
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    plt.legend(loc="best")
    plt.show()
    
    return

# %%
def train(classifier, X, y):
    
    start = time.time()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

    classifier.fit(X_train, y_train) 
                                                        
    end = time.time()

    y_pred = classifier.predict(X_test) 

    df_description(classifier, y_test, y_pred, y_train, X_train, X_test, y_train)

    c_report = metrics.classification_report(y_test, y_pred, output_dict=True) 

    print('\n\n', metrics.classification_report(y_test, y_pred))
    print('\n\n', c_report)
    
    print(len(c_report))
    print(len(y_test))
    print(len(y_pred))
    print(len(y_train))
    print(len(np.unique(y_pred)))

    
    # create a dataframe with X_test and y_test columns
    test_df = pd.concat([X_test, y_test], axis=1)
  

    # add predicted values to the dataframe
    test_df['PREDICTIONS'] = y_pred
   
    
    return test_df

# %%
df_known_class_pred
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
# ...                                  ...                   ...
# 26983  Tf070625722b2312db91de41c22512d87  Unknow Payment Agent
# 9990   Tc8fb82b314543899a9d64e32a0a139c3  Unknow Payment Agent
# 29047  T20c7cd2c7d8131b880812a479917bd11  Unknow Payment Agent
# 48040  T6aa07c6d49883bbbbbec4a95e0570006  Unknow Payment Agent
# 40415  Tc5ee06b2ba413381aedda0c62e4c3b64  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
# ...                ...
# 26983         AUTOZONE
# 9990   Unknow Merchant
# 29047  Unknow Merchant
# 48040       MURPHY USA
# 40415        WALGREENS
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# ...                                                                                                                               ...
# 26983                                                               DEBIT CARD DEBIT auth #* 07-24-2022 AUTOZONE 0187 3 COLUMBUS GA *
# 9990                                                                                       POS PURCHASE * HOTELBOOKINGSE *9059 UT nan
# 29047                                           MISCELLANEOUS DEBIT ATM 0301 1819 * 3233 N COLE RD BOISE ID ATM TRANSACTION FEE $0.50
# 48040                                                            POS PURCHASE MURPHY7754ATWAL BOSSIER CITY LA * *****1766 01/13 10:40
# 40415                                                                       DEBIT CARD DEBIT 03-29-2023 WALGREENS STORE MISSOULA MT *
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True
# ...                     ...               ...              ...
# 26983  Unknow Payment Agent          AUTOZONE             True
# 9990   Unknow Payment Agent   Unknow Merchant            False
# 29047  Unknow Payment Agent   Unknow Merchant            False
# 48040  Unknow Payment Agent        MURPHY USA             True
# 40415  Unknow Payment Agent         WALGREENS             True
#
# [10000 rows x 7 columns]

# %%
#df_unknown_class_pred ================================

# %% [markdown]
# - Multinomial Naive Bayes

# %%
from sklearn.preprocessing import StandardScaler
# # ss = StandardScaler().fit(df_known_class_pred['TRANSACTION_DETAILS'])
# # Xa = ss.transform(df_known_class_pred['TRANSACTION_DETAILS'])

# classifier1 = Pipeline([ ('vectorizer', TfidfVectorizer(stop_words=stopwords.words('english') + list(string.punctuation))), # 
#                         ('scaler', StandardScaler(with_mean=False)),
#                         ('classifier', MultinomialNB(alpha=0.005))])

# train(classifier1, df_known_class_pred['TRANSACTION_DETAILS'], df_known_class_pred['AFS_MECHANT_NAMES'])
# # train(classifier1, Xa, df_known_class_pred['AFS_MECHANT_NAMES'])

# MNB = cls_acc
# Mtime = cls_time
# # print("\n\nMNB: ", MNB)
# # print("Time: ", Mtime)

# %% [markdown]
# - Linear SVC

# %%
from sklearn.svm import LinearSVC

classifier2 = Pipeline([('vectorizer', TfidfVectorizer(stop_words=stopwords.words('english') + list(string.punctuation))), 
                        #('scaler', StandardScaler(with_mean=False)),
                        ('classifier', LinearSVC(C=1.0))])

result_test = train(classifier2, df_known_class_pred['TRANSACTION_DETAILS'], df_known_class_pred['merchant_name'])

SVC = cls_acc
Stime = cls_time
# print("\n\nSVC: ", SVC)
# print("Time: ", Stime)
# Out:
# Accuracy : 0.923
# Number of unique merchants in the test set:  257
# Number of unique merchants in the predicted set:  180
# Number of unique merchants in train set:  473
# Number of unique merchants in OVERS train set:  473
#
# Number of unique "Transaction Details" rows in test set:  7610
# Number of unique "Transaction Details" rows in train set:  1966
#
# Total number of rows in the train set:  8000
# Total number of rows in the test set 2000
# Train accuracy: 0.99775
# Test accuracy: 0.923
#
# ===================================
#
# Percentage of best precision 57.08955223880597
# ===================================
#
# Percentage of best recall 55.59701492537313
# ===================================
#
# Percentage of best f1score 49.25373134328358
# ===================================
# Unknow Merchant: 1161
# AMAZON.COM: 76
# WALMART: 73
# MCDONALD'S: 44
# APPLE STORE: 37
# GOOGLE: 22
# STARBUCKS: 16
# DOLLAR GENERAL: 15
# WALGREENS: 15
# CIRCLE K: 15
#                                      precision    recall  f1-score   support
#
#                           7 ELEVEN       1.00      1.00      1.00        12
#                           ABEBOOKS       0.00      0.00      0.00         1
#                       ACE HARDWARE       1.00      1.00      1.00         2
#                       ACME MARKETS       1.00      1.00      1.00         2
#              ADT SECURITY SERVICES       0.00      0.00      0.00         0
#                         ALBERTSONS       1.00      1.00      1.00         7
#                               ALDI       1.00      0.83      0.91         6
#                           ALLSTATE       1.00      1.00      1.00         1
#                       AMAZON PRIME       0.50      1.00      0.67         1
#                         AMAZON.COM       0.99      1.00      0.99        75
#                          AMAZONVOD       1.00      1.00      1.00         7
#                       ANCESTRY.COM       0.00      0.00      0.00         1
#                        APPLE STORE       1.00      1.00      1.00        37
#                             ARBY'S       1.00      1.00      1.00         1
#                               ARCO       1.00      1.00      1.00         2
#                            AT HOME       0.00      0.00      0.00         1
#                               AT&T       1.00      0.80      0.89        10
#                      AT&T WIRELESS       0.00      0.00      0.00         0
#                      AUNTIE ANNE'S       1.00      1.00      1.00         2
#                           AUTOZONE       1.00      1.00      1.00         2
#                         BAJA FRESH       0.00      0.00      0.00         1
#                    BANK OF AMERICA       0.60      1.00      0.75         3
#                  BATH & BODY WORKS       1.00      1.00      1.00         1
#                  BED BATH & BEYOND       0.00      0.00      0.00         1
#                           BEST BUY       0.67      1.00      0.80         2
#                            BI-MART       0.00      0.00      0.00         1
#                           BIG LOTS       1.00      1.00      1.00         2
#                BJ'S WHOLESALE CLUB       1.00      0.75      0.86         4
#                                BMW       0.00      0.00      0.00         2
#                            BOSCOVS       0.00      0.00      0.00         1
#                           BP AMOCO       1.00      1.00      1.00         1
#                         BROOKSHIRE       0.00      0.00      0.00         2
#                              BROWN       0.00      0.00      0.00         1
#                        BURGER KING       1.00      1.00      1.00         5
#            BURLINGTON COAT FACTORY       1.00      1.00      1.00         2
#                          CARL'S JR       1.00      1.00      1.00         2
#                             CARVEL       0.00      0.00      0.00         1
#             CASEY'S GENERAL STORES       1.00      1.00      1.00         4
#                        CENTURYLINK       1.00      0.50      0.67         2
#                           CHECKERS       0.00      0.00      0.00         1
#          CHEDDAR'S SCRATCH KITCHEN       0.00      0.00      0.00         1
#                 CHEESECAKE FACTORY       0.00      0.00      0.00         1
#                            CHEVRON       1.00      1.00      1.00         4
#                        CHICK-FIL-A       1.00      1.00      1.00         5
#                CHILI'S GRILL & BAR       0.00      0.00      0.00         2
#                   CHIPOTLE MEXICAN       1.00      1.00      1.00         3
#                           CIRCLE K       1.00      1.00      1.00        15
#                              CITGO       0.00      0.00      0.00         1
#                          CITIGROUP       1.00      0.80      0.89         5
#                           CLAIRE'S       0.00      0.00      0.00         1
#                            COMCAST       1.00      1.00      1.00         6
#             COST PLUS WORLD MARKET       1.00      1.00      1.00         1
#                             COSTCO       1.00      1.00      1.00        12
#                     CRACKER BARREL       0.00      0.00      0.00         0
#                   CRICKET WIRELESS       1.00      1.00      1.00         1
#                   CUMBERLAND FARMS       1.00      0.88      0.93         8
#                         CVS HEALTH       0.93      1.00      0.96        13
#                        DAIRY QUEEN       1.00      0.67      0.80         3
#                            DILLONS       1.00      1.00      1.00         1
#       DISNEY PARKS AND EXPERIENCES       1.00      1.00      1.00         1
#                     DOLLAR GENERAL       0.93      1.00      0.97        14
#                        DOLLAR TREE       1.00      1.00      1.00         3
#                     DOMINO'S PIZZA       1.00      1.00      1.00         4
#                     DRAFTKINGS.COM       1.00      1.00      1.00         2
#                     DUNKIN' DONUTS       1.00      1.00      1.00        13
#                 DUTCH BROS. COFFEE       0.00      0.00      0.00         1
#                               EBAY       1.00      1.00      1.00         1
#                         ELECTROLUX       0.00      0.00      0.00         1
#                        EXXON MOBIL       1.00      1.00      1.00         7
#                EZPASS PREPAID TOLL       0.00      0.00      0.00         1
#                      FAMILY DOLLAR       1.00      1.00      1.00         2
#                        FANDUEL.COM       1.00      1.00      1.00         1
#                          FINGERHUT       0.00      0.00      0.00         1
#                     FIREHOUSE SUBS       1.00      1.00      1.00         1
#                         FIVE BELOW       1.00      1.00      1.00         1
#                    FLOOR AND DECOR       0.00      0.00      0.00         1
#                          FOOD LION       1.00      1.00      1.00         4
#                         FRED MEYER       1.00      1.00      1.00         3
#                   FRYS FOOD & DRUG       0.50      1.00      0.67         1
#                                FTD       0.00      0.00      0.00         1
#                            GARNIER       0.00      0.00      0.00         1
#                              GEICO       1.00      1.00      1.00         2
#                     GENERAL MOTORS       1.00      1.00      1.00         1
#                        GIANT EAGLE       1.00      1.00      1.00         3
#                     GIANT FOOD INC       1.00      1.00      1.00         5
#                             GOOGLE       0.91      1.00      0.95        20
#                     GROCERY OUTLET       0.00      0.00      0.00         2
#                               GULF       1.00      0.50      0.67         2
#                                H&M       0.00      0.00      0.00         1
#                          HANNAFORD       1.00      1.00      1.00         1
#                           HARDEE'S       0.00      0.00      0.00         1
#                      HARRIS TEETER       0.00      0.00      0.00         1
#                                HBO       1.00      0.50      0.67         2
#                        HEB GROCERY       1.00      0.25      0.40         4
#                         HELLOFRESH       0.00      0.00      0.00         3
#                        HOBBY LOBBY       1.00      1.00      1.00         1
#              HOLIDAY STATIONSTORES       0.00      0.00      0.00         0
#                          HOLLISTER       0.00      0.00      0.00         1
#                         HOME DEPOT       0.78      1.00      0.88         7
#                              HONDA       0.00      0.00      0.00         1
#                                 HP       1.00      1.00      1.00         1
#                             HUDSON       0.00      0.00      0.00         1
#                               HULU       1.00      1.00      1.00         1
#                        HUNGRY ROOT       0.00      0.00      0.00         1
#                       HY-VEE-FOODS       1.00      1.00      1.00         1
#                                IGA       1.00      1.00      1.00         1
#                               IHOP       0.00      0.00      0.00         3
#                               IKEA       0.00      0.00      0.00         1
#                             INTUIT       1.00      1.00      1.00         1
#                    JACK IN THE BOX       1.00      1.00      1.00         1
#                       JASON'S DELI       0.00      0.00      0.00         1
#                           JCPENNEY       1.00      1.00      1.00         1
#                 JERSEY MIKE'S SUBS       0.00      0.00      0.00         1
#                       JIMMY JOHN'S       1.00      1.00      1.00         1
#                       JOANN FABRIC       1.00      1.00      1.00         1
#                           KEY FOOD       1.00      0.50      0.67         2
#                                KFC       1.00      1.00      1.00         3
#                             KOHL'S       1.00      1.00      1.00         1
#                       KRISPY KREME       0.00      0.00      0.00         1
#                             KROGER       1.00      1.00      1.00         4
#                            KRYSTAL       0.00      0.00      0.00         1
#                     LA FITNESS INC       1.00      0.50      0.67         2
#                          LADY LUCK       0.00      0.00      0.00         1
#                              LESCO       0.00      0.00      0.00         1
#                               LIDL       1.00      1.00      1.00         1
#                            LL BEAN       0.00      0.00      0.00         1
#      LOVES TRAVEL & COUNTRY STORES       0.00      0.00      0.00         0
#                             LOWE'S       1.00      0.92      0.96        13
#                               LYFT       1.00      1.00      1.00         5
#                             MACY'S       1.00      0.83      0.91         6
#                 MARATHON PETROLEUM       1.00      1.00      1.00         1
#                      MARKET BASKET       0.80      1.00      0.89         4
#                          MARSHALLS       1.00      1.00      1.00         3
#                           MARTIN'S       1.00      0.67      0.80         3
#                           MAURICES       0.00      0.00      0.00         1
#             MAVERIK COUNTRY STORES       0.00      0.00      0.00         0
#                         MCDONALD'S       0.93      1.00      0.96        41
#                             MEIJER       1.00      1.00      1.00         2
#                    MICHAELS STORES       0.50      1.00      0.67         1
#                          MICROSOFT       1.00      1.00      1.00         3
#              MOE'S SOUTHWEST GRILL       0.00      0.00      0.00         1
# NATURAL GROCERS BY VITAMIN COTTAGE       1.00      1.00      1.00         1
#                      NBC UNIVERSAL       0.00      0.00      0.00         4
#                            NETFLIX       1.00      1.00      1.00         7
#            NEW YORK LIFE INSURANCE       0.00      0.00      0.00         1
#                           NINTENDO       0.00      0.00      0.00         1
#                          NORDSTROM       1.00      1.00      1.00         1
#                O'REILLY AUTOMOTIVE       1.00      1.00      1.00         1
#                           OLD NAVY       0.00      0.00      0.00         1
#                       OLIVE GARDEN       1.00      1.00      1.00         1
#             OLLIE'S BARGAIN OUTLET       1.00      1.00      1.00         2
#                              OMEGA       0.00      0.00      0.00         1
#                      ON THE BORDER       0.00      0.00      0.00         1
#                            OPTIMUM       1.00      1.00      1.00         1
#                      PANDA EXPRESS       1.00      1.00      1.00         1
#             PANDORA INTERNET RADIO       0.00      0.00      0.00         1
#                       PANERA BREAD       1.00      1.00      1.00         6
#                        PAPA JOHN'S       1.00      1.00      1.00         2
#             PETRO STOPPING CENTERS       0.00      0.00      0.00         1
#                           PETSENSE       0.00      0.00      0.00         1
#                           PETSMART       1.00      1.00      1.00         1
#                        PHILLIPS 66       0.60      1.00      0.75         3
#                PILOT TRAVEL CENTER       1.00      1.00      1.00         1
#                          PIZZA HUT       0.00      0.00      0.00         1
#                     PLANET FITNESS       1.00      1.00      1.00         3
#                        PLAYSTATION       1.00      1.00      1.00         2
#                                PNC       1.00      1.00      1.00         1
#                     POLLO TROPICAL       0.00      0.00      0.00         2
#                           POPEYE'S       1.00      1.00      1.00         3
#                      PRICE CHOPPER       1.00      1.00      1.00         1
#                        PROGRESSIVE       1.00      0.50      0.67         4
#               PUBLIX SUPER MARKETS       1.00      1.00      1.00        12
#                             QT GAS       1.00      1.00      1.00        10
#                            QUIZNOS       0.00      0.00      0.00         1
#                      RAINBOW FOODS       0.00      0.00      0.00         1
#                     RAISING CANE'S       0.00      0.00      0.00         1
#              RED ROBIN RESTAURANTS       0.00      0.00      0.00         1
#                      RENT-A-CENTER       0.00      0.00      0.00         1
#                           RITE AID       1.00      1.00      1.00         4
#                               ROKU       0.75      1.00      0.86         3
#                        ROSS STORES       0.00      0.00      0.00         0
#                  ROUND TABLE PIZZA       0.00      0.00      0.00         1
#                        ROYAL FARMS       1.00      1.00      1.00         1
#                        RULER FOODS       1.00      1.00      1.00         1
#                            SAFEWAY       1.00      1.00      1.00         9
#                            SALOMON       1.00      1.00      1.00         2
#                         SAM'S CLUB       1.00      1.00      1.00         3
#                        SARKU JAPAN       1.00      1.00      1.00         1
#                         SAVE A LOT       0.00      0.00      0.00         2
#                       SCHLOTZSKY'S       0.00      0.00      0.00         1
#                    SCHNUCKS MARKET       1.00      1.00      1.00         2
#                          SEA WORLD       0.00      0.00      0.00         1
#                               SELF       0.00      0.00      0.00         1
#                        SHAKE SHACK       0.00      0.00      0.00         0
#                             SHEETZ       1.00      1.00      1.00         5
#                          SHELL OIL       0.93      1.00      0.96        13
#                      SHOE CARNIVAL       0.00      0.00      0.00         1
#                         SHOE DEPT.       1.00      1.00      1.00         1
#            SHOPPERS FOOD WAREHOUSE       1.00      1.00      1.00         1
#                           SHOPRITE       1.00      1.00      1.00         1
#                          SIRIUS XM       1.00      1.00      1.00         2
#                           SLING TV       1.00      1.00      1.00         1
#                      SMART & FINAL       0.00      0.00      0.00         1
#                         SMARTSTYLE       0.00      0.00      0.00         1
#                            SMITH'S       0.00      0.00      0.00         3
#                     SONIC DRIVE-IN       1.00      1.00      1.00         5
#                 SOUTHWEST AIRLINES       1.00      1.00      1.00         1
#                           SPECTRUM       1.00      1.00      1.00         3
#                           SPEEDWAY       1.00      1.00      1.00         7
#                   SPIRIT HALLOWEEN       0.00      0.00      0.00         1
#                             SPRINT       1.00      1.00      1.00         1
#                            SPROUTS       1.00      1.00      1.00         1
#                            STAPLES       0.00      0.00      0.00         2
#                          STARBUCKS       1.00      0.94      0.97        17
#               STATE FARM INSURANCE       1.00      1.00      1.00         6
#                      STEAK-N-SHAKE       0.00      0.00      0.00         1
#                              STEAM       1.00      1.00      1.00         1
#                        STOP & SHOP       0.67      1.00      0.80         2
#                             SUBWAY       1.00      1.00      1.00         6
#                           SUNDANCE       0.00      0.00      0.00         1
#                             SUNOCO       1.00      1.00      1.00         5
#                           T-MOBILE       1.00      1.00      1.00         3
#                          TACO BELL       1.00      1.00      1.00         9
#                             TARGET       1.00      1.00      1.00        11
#                            TD BANK       0.00      0.00      0.00         1
#                             TEXACO       1.00      0.50      0.67         2
#                    TEXAS ROADHOUSE       1.00      1.00      1.00         1
#                        TGI FRIDAYS       1.00      0.50      0.67         2
#                   THE FRESH MARKET       0.00      0.00      0.00         3
#                       THORNTON OIL       1.00      1.00      1.00         1
#                      TIJUANA FLATS       0.00      0.00      0.00         1
#                            TJ MAXX       1.00      1.00      1.00         2
#                          TOM THUMB       0.00      0.00      0.00         2
#             TRACTOR SUPPLY COMPANY       1.00      1.00      1.00         1
#                       TRADER JOE'S       1.00      1.00      1.00         2
#                           TRAVELER       1.00      1.00      1.00         3
#             TROPICAL SMOOTHIE CAFE       0.00      0.00      0.00         1
#                           TURBOTAX       1.00      1.00      1.00         1
#              TWIN PEAKS RESTAURANT       0.00      0.00      0.00         1
#                               UBER       0.88      0.88      0.88         8
#                           UBEREATS       0.00      0.00      0.00         1
#                               ULTA       1.00      1.00      1.00         2
#              UNIVERSAL THEME PARKS       0.00      0.00      0.00         1
#                               USAA       1.00      1.00      1.00         1
#                    Unknow Merchant       0.90      0.98      0.93      1064
#                            VERIZON       1.00      1.00      1.00         3
#                   VERIZON WIRELESS       1.00      1.00      1.00         6
#                  VICTORIA'S SECRET       1.00      1.00      1.00         1
#                             VIVINT       1.00      0.50      0.67         2
#                          WALGREENS       1.00      1.00      1.00        15
#                             WALLIS       0.00      0.00      0.00         1
#                            WALMART       0.99      1.00      0.99        72
#                               WAWA       1.00      1.00      1.00         6
#                        WAYFAIR.COM       1.00      1.00      1.00         1
#               WEGMANS FOOD MARKETS       1.00      0.50      0.67         2
#                    WEIGHT WATCHERS       0.00      0.00      0.00         1
#                       WEIS MARKETS       1.00      1.00      1.00         1
#                        WELLS FARGO       1.00      1.00      1.00         7
#                            WENDY'S       1.00      1.00      1.00         7
#                 WHOLE FOODS MARKET       1.00      1.00      1.00         2
#                              WINCO       1.00      1.00      1.00         5
#                         WINN-DIXIE       1.00      1.00      1.00         1
#                         YOUTUBE TV       0.00      0.00      0.00         1
#                               ZARA       0.00      0.00      0.00         1
#                             ZAXBYS       1.00      1.00      1.00         1
#
#                           accuracy                           0.92      2000
#                          macro avg       0.63      0.62      0.62      2000
#                       weighted avg       0.88      0.92      0.90      2000
#
#
#
#  {'7 ELEVEN': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12}, 'ABEBOOKS': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'ACE HARDWARE': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'ACME MARKETS': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'ADT SECURITY SERVICES': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'ALBERTSONS': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7}, 'ALDI': {'precision': 1.0, 'recall': 0.8333333333333334, 'f1-score': 0.9090909090909091, 'support': 6}, 'ALLSTATE': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1}, 'AMAZON PRIME': {'precision': 0.5, 'recall': 1.0, 'f1-score': 0.6666666666666666, 'support': 1}, 'AMAZON.COM': {'precision': 0.9868421052631579, 'recall': 1.0, 'f1-score': 0.9933774834437086, 'support': 75}, 'AMAZONVOD': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7}, 'ANCESTRY.COM': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'APPLE STORE': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 37}, "ARBY'S": {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1}, 'ARCO': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'AT HOME': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'AT&T': {'precision': 1.0, 'recall': 0.8, 'f1-score': 0.888888888888889, 'support': 10}, 'AT&T WIRELESS': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, "AUNTIE ANNE'S": {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'AUTOZONE': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'BAJA FRESH': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'BANK OF AMERICA': {'precision': 0.6, 'recall': 1.0, 'f1-score': 0.7499999999999999, 'support': 3}, 'BATH & BODY WORKS': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1}, 'BED BATH & BEYOND': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'BEST BUY': {'precision': 0.6666666666666666, 'recall': 1.0, 'f1-score': 0.8, 'support': 2}, 'BI-MART': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'BIG LOTS': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, "BJ'S WHOLESALE CLUB": {'precision': 1.0, 'recall': 0.75, 'f1-score': 0.8571428571428571, 'support': 4}, 'BMW': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2}, 'BOSCOVS': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'BP AMOCO': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1}, 'BROOKSHIRE': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2}, 'BROWN': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'BURGER KING': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5}, 'BURLINGTON COAT FACTORY': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, "CARL'S JR": {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'CARVEL': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, "CASEY'S GENERAL STORES": {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4}, 'CENTURYLINK': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 2}, 'CHECKERS': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, "CHEDDAR'S SCRATCH KITCHEN": {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'CHEESECAKE FACTORY': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'CHEVRON': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4}, 'CHICK-FIL-A': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5}, "CHILI'S GRILL & BAR": {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2}, 'CHIPOTLE MEXICAN': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3}, 'CIRCLE K': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 15}, 'CITGO': {'precision': 0.0, 'reca ...
# 268
# 2000
# 2000
# 8000
# 180
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Olimpio.Dasilva\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
result_test.head(100)
# Out:
#                                                                                              TRANSACTION_DETAILS  \
# 49919                                                     Point Of Sale Withdrawal PAYPAL *STARBUCKS *7733 WA US
# 49367                                                      Withdrawal Debit WM SUPERC Wal-Mart Sup CLERMONT FLUS
# 20202             Withdrawal MasterCard DC CMSVEND*CV HOUS 15951 PARK ROW HOUSTON TX Date 03/16/23 5 *198 2 5814
# 48211  Withdrawal Signature PHILLIPS 66 - U GAS LITTL HIGH RIDGE MO Date 02/27/23 ***80400 5541 %% Card 15 #3788
# 49181                                                  ELECTRONIC WITHDRAWAL WELLS FARGO CARDCCPYMT * Eff. Date:
# ...                                                                                                          ...
# 9866                                              CKCD DEBIT 7790 11/26 19:33 LOWES #009 07* 866-483-7521 NC nan
# 17282                                                              POS Transaction KLOVER APP BOOST Chicago ILUS
# 19766                                    Card purchase AMZN Mktp US*HC5YR4130 5942 (2023-03-15) Amzn.com/bill WA
# 35395                                                      Card purchase Google King 5734 (2022-04-27) 650-*0 CA
# 32572          Withdrawal PFCU CHECK CARD ULTA 1390 PHILADELPHIA PA Date 02/24/23 ***01021 5977 %% Card 25 #6397
#
#          merchant_name      PREDICTIONS
# 49919        STARBUCKS        STARBUCKS
# 49367          WALMART          WALMART
# 20202  Unknow Merchant  Unknow Merchant
# 48211      PHILLIPS 66      PHILLIPS 66
# 49181      WELLS FARGO      WELLS FARGO
# ...                ...              ...
# 9866            LOWE'S           LOWE'S
# 17282  Unknow Merchant  Unknow Merchant
# 19766       AMAZON.COM       AMAZON.COM
# 35395           GOOGLE           GOOGLE
# 32572             ULTA             ULTA
#
# [100 rows x 3 columns]

# %%
df_result_test = pd.DataFrame(result_test)

# %%
result_csv = df_result_test.head(200)

# %%
result_csv
# Out:
#                                                                                              TRANSACTION_DETAILS  \
# 49919                                                     Point Of Sale Withdrawal PAYPAL *STARBUCKS *7733 WA US
# 49367                                                      Withdrawal Debit WM SUPERC Wal-Mart Sup CLERMONT FLUS
# 20202             Withdrawal MasterCard DC CMSVEND*CV HOUS 15951 PARK ROW HOUSTON TX Date 03/16/23 5 *198 2 5814
# 48211  Withdrawal Signature PHILLIPS 66 - U GAS LITTL HIGH RIDGE MO Date 02/27/23 ***80400 5541 %% Card 15 #3788
# 49181                                                  ELECTRONIC WITHDRAWAL WELLS FARGO CARDCCPYMT * Eff. Date:
# ...                                                                                                          ...
# 27461                                 CHECK/DEBIT VSA PUR GIFTSHOPHYATTREGENCYORL ORLANDO FL (03/10/23 19:49:44)
# 39515             Withdrawal PFCU Check Card KFC K* PHILADELPHIA PA Date 02/02/23 ***00758 5814 %% Card 30 #1285
# 2854                                                                   Withdrawal Debit NITRADO NET KARLSRUHE DE
# 37312                          Bill payment Card purchase AT&T *PAYMENT 4899 (2023-03-03) 800-288-2020 FL IN7900
# 8976                                                               External Withdrawal CAPITAL ONE =- ONLINE PMT
#
#          merchant_name      PREDICTIONS
# 49919        STARBUCKS        STARBUCKS
# 49367          WALMART          WALMART
# 20202  Unknow Merchant  Unknow Merchant
# 48211      PHILLIPS 66      PHILLIPS 66
# 49181      WELLS FARGO      WELLS FARGO
# ...                ...              ...
# 27461  Unknow Merchant  Unknow Merchant
# 39515              KFC              KFC
# 2854   Unknow Merchant  Unknow Merchant
# 37312             AT&T             AT&T
# 8976   Unknow Merchant  Unknow Merchant
#
# [200 rows x 3 columns]

# %%
# save the dataframe to a CSV file
#result_csv.to_csv('result_MIX_NoPrePro.csv', index=False)

# %%
# # call function to train and predict using the iris dataset
# predicted_df = train_and_predict(iris, 'class')

# # display the resulting dataframe
# predicted_df.head()

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)

# %%
result_csv.head(100)
# Out:
#                                                                                                                                                                    TRANSACTION_DETAILS  \
# 49919                                                                                                                           Point Of Sale Withdrawal PAYPAL *STARBUCKS *7733 WA US
# 49367                                                                                                                            Withdrawal Debit WM SUPERC Wal-Mart Sup CLERMONT FLUS
# 20202                                                                                   Withdrawal MasterCard DC CMSVEND*CV HOUS 15951 PARK ROW HOUSTON TX Date 03/16/23 5 *198 2 5814
# 48211                                                                        Withdrawal Signature PHILLIPS 66 - U GAS LITTL HIGH RIDGE MO Date 02/27/23 ***80400 5541 %% Card 15 #3788
# 49181                                                                                                                        ELECTRONIC WITHDRAWAL WELLS FARGO CARDCCPYMT * Eff. Date:
# 219                                                                          Withdrawal #** WM SUPERCENTER #824 Wal-Mart Store ALBUQUERQUE ( NM Card 8468 Merchant Category Code: 5310
# 20339                                                                                                                  Card purchase LOWE'S #1151 5200 (2023-02-05) PORT ARTHUR TX 001
# 8549                                                                                    DBT PURCHASE ON 04/25 @ 22:08 CITY OF BALTIM CITY OF BALTIMORE 410-396-3971 MD CARD NBR: -8749
# 14294                                                                                                                         Point Of Sale Withdrawal JERRYS FOR ALL SEASDUNMORE PAUS
# 1699                                                                                 Withdrawal DEBIT CARD HOME* AHS.COM FRONTDOORHOME TN Date 01/27/23 ***89390 6300 %% Card 15 #8935
# 22363                                                                             ATM WTHDRWL ON 03/12 @ 19:32 4411 E. PACIFIC HIGHWAY 4411 E. PACIFIC HIGHWAY FIFE WA CARD NBR: -2510
# 5376                                                                                                                                   POS Withdrawal CHICK-FIL-A #02173 AVONDALE AZUS
# 38738                                                                                     Withdrawal OSSORIO BAKERY & CAFE COCOA FL Date 03/09/23 ** 5812 %% Card 25 #5481 %% MCC 5812
# 32358                                                                            Withdrawal MCSIGNATURE TRACFONE *AIRTIME TRACFONE.COM FL Date 07/19/22 ***43285 4814 %% Card 19 #1799
# 25976                                                                                                                       Withdrawal TOM THUMB #1784 MESQUITE TX %% Card 15 #0001 #*
# 40040                                                                                                                       Stash Your Cash Withdrawal Transferred to Acct#: xxxxx7800
# 40233                                         External Withdrawal SMARTPAY REWARDS 4INFO 877-403-2222 PREAUTHPMT CUMBERLAND F-4548 NORTH MAI FALL RIVER MA 6892 **5754CUMBERLAND F-454
# 18265                                                                                                                                       External Withdrawal CONSOLIDATEDCCU - CCCU
# 25349                                                                                                       DBT PURCHASE ON 03/09 @ 18:18 ALBERTSONS #3106 PUYALLUP WA CARD NBR: -6417
# 46691                                                                                                       Withdrawal #* MCDONALD'S F579 529 SW CUTOFF WORCESTER MA %% Card 15 #*6586
# 41136                                                                                                                                               Purchase TACO BELL * LAWRENCE KSUS
# 1760                                                                                                                                        WELLS FARGO AUTO ONLINE PMT CKF*388POS nan
# 43338                                                                                                                                              PHO 79 DAVIE FLUS : POS Transaction
# 31183                                                                     Withdrawal Debit Signature PANERA BREAD #* P 9480 DORCHESTER RD Date 02/05/23 9 *807 5 5814 %% Card 15 #4773
# 25936                                                                                          Withdrawal #* POS WM SUPERCENTER # Wal-Mart Super Cen EXCELSIOR SPR MO %% Card 15 #6601
# 16168                                                        Withdrawal DEBIT CARD Subway 16591 11425 S.Dupont Hwy Felton DE Date 02/03/22 1 *0396 4 5814 %% Card 15 #8847 %% MCC 5814
# 43354                                                                                                                                        POS Transaction DUNKIN #* AUSTINTOWN OHUS
# 12234                                                                                                                        Withdrawal Debit AMZN Mktp US*H29M881G1 Amzn.com/billWAUS
# 39202                                                                                POS PURCHASE ON 01/26 @ 17:13 WINCO FOODS #16 18301 Gem Heights Drive Puyallup WA CARD NBR: -5515
# 23061                                                                                              DEBIT CARD DEBIT 03-25-2023 FAMILY DOLLAR # 24549 HIGHWAY 1 PLAQUEMI Eff. Date: *00
# 9912                                                                                                                                      POS PURCHASE WHERE'S RUFUS SOCIAL C TYLER TX
# 39846                                                                                                                                         ACH Withdrawal SAMS CLUB MC - ONLINE PMT
# 33806                                                                       Withdrawal Debit Card AMZN Mktp US*JR6PL15V3 Amzn.com/bill WA Date 01/30/23 ***43287 5942 %% Card 15 #8849
# 10946                                                                                                                    Withdrawal Debit Card Withdrawal CHEDDARS **9 FAYETTEVILLE NC
# 33032                                                                                                        POS Withdrawal (FIP) Speedway 482 M Speedway 482 Main Leominster MA(9951)
# 15748                                                                       Withdrawal Home Banking Transfer To SMITH,MYRTIS *5015 Share 0030 SecureLink 02/10/2023 05:57 * - mortgage
# 37038                                                                                                   DEBIT CARD DEBIT ref #** auth #* 01-13-2022 WALMART.COM AA *6546 AR Eff. Date:
# 15393                                                                                                                                     External Withdrawal CAPITAL ONE - ONLINE PMT
# 11599                                                                                                                                            ELECTRONIC WITHDRAWAL VENMO PAYMENT *
# 26542                                                                                                                              Withdrawal Debit ZEL*JAMIL ESTRADA Visa Direct AZUS
# 27055                                                                                                                                                  Point Of Sale Withdrawal BILLIE
# 2260                                                                                                                                         #* SAVEWAY MARKET 1200 SHOUP ST SALMON ID
# 17288                                                                                                                                    Withdrawal Debit ARBYS 5423 WINTER SPRINGFLUS
# 19378                                                                                                                                 Point Of Sale Withdrawal AMAZON.COM SEATTLE WAUS
# 45771                                                                                                Withdrawal SHELL OIL *387 CRYSTAL SPRIN MS Date 01/04/23 * 5542 %% Card 35 #26704
# 15248                                                                                                                                DDA PUR CVS CarePa CVS CarePass 833-320-2273 RI *
# 2536                                                                                                                           DEBIT CARD DEBIT 03-24-2023 ICTICKETS 877-263-9372 ID *
# 22678                                                                                                        Withdrawal HAPPY DRAGON DECATUR GA Date 04/29/22 * 5812 %% Card 35 #60007
# 10063                                                                                                                            Point Of Sale Withdrawal Walmart.com Bentonville ARUS
# 872                                                                                                                  DEBIT CARD DEBIT auth #* 02-19-2023 APPLE.COM/BILL CUPERTINO CA *
# 13666                                                                                                   Withdrawal #* WM SUPERCENTER # Wal-Mart Super Cent TUCKER GA %% Card 35 #96663
# 37082                                                                                                                                 Point Of Sale Withdrawal HUFFS THOMPSONS STNTNUS
# 10472                                                                                                                Withdrawal #* MCDONALD'S F389 3535 BRIARWOOD BEND MONT BELVIEU TX
# 21749                                                                                                                                                  MAVERIK #459 PLEASANT GROV, nan
# 49683                                                                                                                                       ELECTRONIC WITHDRAWAL Connexus ExtrnlTfr *
# 3680                                                                                                                                        POS Transaction KLARNA INC KLARNA.COM OHUS
# 10875                                                                                                                                                Purchase QT 228 NORTH KANSAS MOUS
# 42367                                                                                  Withdrawal MasterCard DC TACO BELL 02572 8302 NORTH HWY 146 BAYTOWN Date 02/12/23 0 *979 5 5814
# 49202                                                                                                                                                Withdrawal %% TCode01 CD 9,000.00
# 47164                                                                                                                          Stash My Cash Withdrawal Transferred to Savings Account
# 21763                                                                                                                             Withdrawal Debit Audible*1U29Q80U1 Amzn.com/billNJUS
# 40565                                                                                                                           WITHDRAWAL POS 0310 1235 * AMAZON.COM*HG5EK SEATTLE WA
# 41331                                                                                                            Withdrawal #* FRESH FOODS #1 47 GREEN ST CLARKTON NC %% Card 15 #3025
# 36752                                                               Withdrawal Consumer Debit EDGEMERE MINI M 734 GRAFTON STREET WORCEST Date 02/02/23 0 *948 1 5499 %% Card 15 #*1301
# 33569                                                                            Withdrawal Signature base EB FOODIELAND NIGHT M *7200 CA Date 03/15/23 ***23228 7399 %% Card 25 #3424
# 39709                                                                                                                              POS Withdrawal HY-VEE LEE'S SUMMITLEE'S SUMMIT MOUS
# 2976                                                                                                                                  Withdrawal Debit ACTION CHURCH WWW.THEACTIONFLUS
# 49267                                                                                                                          Withdrawal Debit SP SOMETHING NEW BRI HTTPSSOMETHINIDUS
# 47474                                                                                                        DBT PURCHASE ON 03/24 @ 18:19 RED ROBIN NO 165 OLYMPIA WA CARD NBR: -4715
# 38294                                                                                  Withdrawal MasterCard DC STARBUCKS APTO AV CAP CARLOS LEON SN N MEX Date 02/14/23 3 *810 6 5814
# 9582                                                                                                                              Withdrawal Debit Card Withdrawal IHOP * HOLLYWOOD FL
# 11152                                                                                                                          DEBIT CARD DEBIT 03-09-2023 ALBERTSONS #0169 BOISE ID *
# 35809                                                                                                                                     Withdrawal Debit KISSME BEAUTY KISSMMEE FLUS
# 17541  Withdrawal TARGET DEBIT CRD Location - TARGET -2365 Queen Creek AZ / Terminal ID: 177 TYPE: ACH TRAN ID: *5170 DATA: 001 CO: TARGET DEBIT CRD %% ACH ECC POS %% ACH Trace **760
# 35141                                                                                                                                   ELECTRONIC WITHDRAWAL Acorns Invest Transfer *
# 41821                                                                                                                         ACH Withdrawal COMP NAME: AMANDA YODERS DESC: BILL PAYMT
# 44624                                                                      CGX BASE SAN JUAN SAN JUAN PR Withdrawal @ CGX BASE SAN JUAN SAN JUAN PR Trace #8659 (eff. date 12/12/2022)
# 43115                                                                                                                                  Withdrawal Debit WAL-MART #0705 MOUNT DORA FLUS
# 19261                                                                                     Withdrawal Debit Card PUBLIX #1746 PENSACOLA FL Date 11/05/22 ***30535 5411 %% Card 15 #5267
# 49868                                                                                                                                    Purchase THE ELMS HOTEL F&B EXCELSIOR SPRMOUS
# 13071                                                                                                                  DEBIT CARD DEBIT 02-24-2023 HONEY BEE TEA MANCHESTER MO auth #*
# 16170                                                                         Withdrawal DEBIT CARD Amazon.com*H27D54XO1 Amzn.com/bill WA Date 11/05/22 ***01130 5942 %% Card 15 #5803
# 3115                                                                                                   Withdrawal Debit Card LOS FAVORITOS 3 SCOTTSDALE AZ Date 01/25/23 ***75909 5812
# 2896                                                                      Withdrawal EXXONMOBIL TYPE: ONLINE PMT CO: EXXONMOBIL NAME: JODIE FUHRMANN %% ACH ECC WEB %% ACH Trace **034
# 41647                                                                                                                                       Withdrawal INTERNET TRANSFER TO : XXXX7809
# 26911                                                                                                          Point Of Sale Withdrawal WAL WAL-MART SUPER * 2065 WAL-SAMS KNOXVILLE (
# 25063                                                               Withdrawal Consumer Debit PRICE CHOPPER # 2 WORCESTER ROAD WEBSTER M Date 09/24/22 0 *946 3 5411 %% Card 15 #*7059
# 19663                                                                                                     Withdrawal TEXACO *7 LITHIA SPRING GA Date 01/16/23 * 5542 %% Card 35 #12231
# 37754                                                                                                                                    Withdrawal POS DOLLAR GENERAL # DG *228 STATE
# 35913                                                                                                                   DEBIT CARD DEBIT 02-02-2023 AMZN Mktp US*TK3 Amzn.com/billWA *
# 5612                                                                                                                                                     EPAY CHASE CREDIT CRD ID*9224
# 948                                                                                Withdrawal CONSUMER DEBIT CASH APP*RYAN HOLLI *4551 CA Date 11/30/22 ***65140 4829 %% Card 15 #5803
# 5974                                                                         Withdrawal Signature AMZN Mktp US*H87E65LX0 Amzn.com/bill WA Date 10/18/22 ***59990 5942 %% Card 15 #1219
# 11092                                                                                                                           DEBIT CARD DEBIT 07-31-2022 WINCO FOODS #11 Nampa ID *
# 49449                                                                                                                          DEBIT CARD DEBIT 03-21-2023 THE HOME DEPOT # EAGLE ID *
# 9866                                                                                                                    CKCD DEBIT 7790 11/26 19:33 LOWES #009 07* 866-483-7521 NC nan
# 17282                                                                                                                                    POS Transaction KLOVER APP BOOST Chicago ILUS
# 19766                                                                                                          Card purchase AMZN Mktp US*HC5YR4130 5942 (2023-03-15) Amzn.com/bill WA
# 35395                                                                                                                            Card purchase Google King 5734 (2022-04-27) 650-*0 CA
# 32572                                                                                Withdrawal PFCU CHECK CARD ULTA 1390 PHILADELPHIA PA Date 02/24/23 ***01021 5977 %% Card 25 #6397
#
#                    merchant_name           PREDICTIONS
# 49919                  STARBUCKS             STARBUCKS
# 49367                    WALMART               WALMART
# 20202            Unknow Merchant       Unknow Merchant
# 48211                PHILLIPS 66           PHILLIPS 66
# 49181                WELLS FARGO           WELLS FARGO
# 219                      WALMART               WALMART
# 20339                     LOWE'S                LOWE'S
# 8549             Unknow Merchant       Unknow Merchant
# 14294            Unknow Merchant       Unknow Merchant
# 1699             Unknow Merchant       Unknow Merchant
# 22363            Unknow Merchant       Unknow Merchant
# 5376                 CHICK-FIL-A           CHICK-FIL-A
# 38738            Unknow Merchant       Unknow Merchant
# 32358            Unknow Merchant       Unknow Merchant
# 25976                  TOM THUMB       Unknow Merchant
# 40040            Unknow Merchant       Unknow Merchant
# 40233           CUMBERLAND FARMS      CUMBERLAND FARMS
# 18265            Unknow Merchant       Unknow Merchant
# 25349                 ALBERTSONS            ALBERTSONS
# 46691                 MCDONALD'S            MCDONALD'S
# 41136                  TACO BELL             TACO BELL
# 1760                 WELLS FARGO           WELLS FARGO
# 43338            Unknow Merchant       Unknow Merchant
# 31183               PANERA BREAD          PANERA BREAD
# 25936                    WALMART               WALMART
# 16168                     SUBWAY                SUBWAY
# 43354             DUNKIN' DONUTS        DUNKIN' DONUTS
# 12234                 AMAZON.COM            AMAZON.COM
# 39202                      WINCO                 WINCO
# 23061              FAMILY DOLLAR         FAMILY DOLLAR
# 9912             Unknow Merchant       Unknow Merchant
# 39846                 SAM'S CLUB            SAM'S CLUB
# 33806                 AMAZON.COM            AMAZON.COM
# 10946  CHEDDAR'S SCRATCH KITCHEN       Unknow Merchant
# 33032                   SPEEDWAY              SPEEDWAY
# 15748            Unknow Merchant       Unknow Merchant
# 37038                    WALMART               WALMART
# 15393            Unknow Merchant       Unknow Merchant
# 11599            Unknow Merchant       Unknow Merchant
# 26542            Unknow Merchant       Unknow Merchant
# 27055            Unknow Merchant       Unknow Merchant
# 2260                     SALOMON               SALOMON
# 17288                     ARBY'S                ARBY'S
# 19378                 AMAZON.COM            AMAZON.COM
# 45771                  SHELL OIL             SHELL OIL
# 15248                 CVS HEALTH            CVS HEALTH
# 2536             Unknow Merchant       Unknow Merchant
# 22678            Unknow Merchant       Unknow Merchant
# 10063                    WALMART               WALMART
# 872                  APPLE STORE           APPLE STORE
# 13666                    WALMART               WALMART
# 37082            Unknow Merchant       Unknow Merchant
# 10472                 MCDONALD'S            MCDONALD'S
# 21749            Unknow Merchant       Unknow Merchant
# 49683            Unknow Merchant       Unknow Merchant
# 3680             Unknow Merchant       Unknow Merchant
# 10875                     QT GAS                QT GAS
# 42367                  TACO BELL             TACO BELL
# 49202            Unknow Merchant       Unknow Merchant
# 47164            Unknow Merchant       Unknow Merchant
# 21763                 AMAZON.COM            AMAZON.COM
# 40565                 AMAZON.COM            AMAZON.COM
# 41331            Unknow Merchant       Unknow Merchant
# 36752            Unknow Merchant       Unknow Merchant
# 33569            Unknow Merchant       Unknow Merchant
# 39709               HY-VEE-FOODS          HY-VEE-FOODS
# 2976             Unknow Merchant       Unknow Merchant
# 49267            Unknow Merchant       Unknow Merchant
# 47474      RED ROBIN RESTAURANTS       Unknow Merchant
# 38294                  STARBUCKS       Unknow Merchant
# 9582                        IHOP       Unknow Merchant
# 11152                 ALBERTSONS            ALBERTSONS
# 35809            Unknow Merchant       Unknow Merchant
# 17541                     TARGET                TARGET
# 35141            Unknow Merchant       Unknow Merchant
# 41821            Unknow Merchant       Unknow Merchant
# 44624            Unknow Merchant       Unknow Merchant
# 43115                    WALMART               WALMART
# 19261       PUBLIX SUPER MARKETS  PUBLIX SUPER MARKETS
# 49868            Unknow Merchant       Unknow Merchant
# 13071            Unknow Merchant       Unknow Merchant
# 16170                 AMAZON.COM            AMAZON.COM
# 3115             Unknow Merchant       Unknow Merchant
# 2896                 EXXON MOBIL           EXXON MOBIL
# 41647            Unknow Merchant       Unknow Merchant
# 26911                    WALMART               WALMART
# 25063              PRICE CHOPPER         PRICE CHOPPER
# 19663                     TEXACO                TEXACO
# 37754             DOLLAR GENERAL        DOLLAR GENERAL
# 35913                 AMAZON.COM            AMAZON.COM
# 5612             Unknow Merchant       Unknow Merchant
# 948              Unknow Merchant       Unknow Merchant
# 5974                  AMAZON.COM            AMAZON.COM
# 11092                      WINCO                 WINCO
# 49449                 HOME DEPOT            HOME DEPOT
# 9866                      LOWE'S                LOWE'S
# 17282            Unknow Merchant       Unknow Merchant
# 19766                 AMAZON.COM            AMAZON.COM
# 35395                     GOOGLE                GOOGLE
# 32572                       ULTA                  ULTA

# %%
df_known_class_pred
# Out:
#                           transaction_id         payment_agent  \
# 43572  T312b7d75b3063a88a450e7fb09912aed  Unknow Payment Agent
# 3784   T9a00dbbc029d3b4788bf4d5003f7a200  Unknow Payment Agent
# 48818  Te0b7145f03be3a55b1167d96389ddada  Unknow Payment Agent
# 29107  T8febfbd1070c30059ea0150113232244                PAYPAL
# 35045  Tdb48c9dd884c340388c813ede2a3f211  Unknow Payment Agent
# ...                                  ...                   ...
# 26983  Tf070625722b2312db91de41c22512d87  Unknow Payment Agent
# 9990   Tc8fb82b314543899a9d64e32a0a139c3  Unknow Payment Agent
# 29047  T20c7cd2c7d8131b880812a479917bd11  Unknow Payment Agent
# 48040  T6aa07c6d49883bbbbbec4a95e0570006  Unknow Payment Agent
# 40415  Tc5ee06b2ba413381aedda0c62e4c3b64  Unknow Payment Agent
#
#          merchant_name  \
# 43572  BANK OF AMERICA
# 3784   Unknow Merchant
# 48818  Unknow Merchant
# 29107  Unknow Merchant
# 35045  Unknow Merchant
# ...                ...
# 26983         AUTOZONE
# 9990   Unknow Merchant
# 29047  Unknow Merchant
# 48040       MURPHY USA
# 40415        WALGREENS
#
#                                                                                                                   TRANSACTION_DETAILS  \
# 43572  Withdrawal BK OF AMER VISA TYPE: ONLINE PMT ID: *0000 CO: BK OF AMER VISA NAME: SHARP,DARREN %% ACH ECC WEB %% ACH Trace **158
# 3784                                                                                 Withdrawal Debit ADORA K-BEAUTY COS ORLANDO FLUS
# 48818              Withdrawal PECO ENERGY COMP TYPE: BILLPAY ID: *0160 CO: PECO ENERGY COMP NAME: DAMIKA CORNELIUS %% ACH Trace **863
# 29107                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: ROBERT ERICKSON
# 35045          Withdrawal DEBIT CARD AUTOMATIC VENDING SANTA FE NM Date 12/12/22 ***94423 5814 Card 5848 Merchant Category Code: 5814
# ...                                                                                                                               ...
# 26983                                                               DEBIT CARD DEBIT auth #* 07-24-2022 AUTOZONE 0187 3 COLUMBUS GA *
# 9990                                                                                       POS PURCHASE * HOTELBOOKINGSE *9059 UT nan
# 29047                                           MISCELLANEOUS DEBIT ATM 0301 1819 * 3233 N COLE RD BOISE ID ATM TRANSACTION FEE $0.50
# 48040                                                            POS PURCHASE MURPHY7754ATWAL BOSSIER CITY LA * *****1766 01/13 10:40
# 40415                                                                       DEBIT CARD DEBIT 03-29-2023 WALGREENS STORE MISSOULA MT *
#
#          AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 43572  Unknow Payment Agent   BANK OF AMERICA             True
# 3784   Unknow Payment Agent   Unknow Merchant            False
# 48818  Unknow Payment Agent   Unknow Merchant            False
# 29107                PAYPAL   Unknow Merchant            False
# 35045  Unknow Payment Agent   Unknow Merchant             True
# ...                     ...               ...              ...
# 26983  Unknow Payment Agent          AUTOZONE             True
# 9990   Unknow Payment Agent   Unknow Merchant            False
# 29047  Unknow Payment Agent   Unknow Merchant            False
# 48040  Unknow Payment Agent        MURPHY USA             True
# 40415  Unknow Payment Agent         WALGREENS             True
#
# [10000 rows x 7 columns]

# %%
#result_csv["LEN_WORDS"] = result_csv["TRANSACTION_DETAILS"].apply(lambda x: len(str(x).split()))

# %%
#result_csv["LEN_WORDS"].describe()

# %%
result_csv
# Out:
#                                                                                                                                                                    TRANSACTION_DETAILS  \
# 49919                                                                                                                           Point Of Sale Withdrawal PAYPAL *STARBUCKS *7733 WA US
# 49367                                                                                                                            Withdrawal Debit WM SUPERC Wal-Mart Sup CLERMONT FLUS
# 20202                                                                                   Withdrawal MasterCard DC CMSVEND*CV HOUS 15951 PARK ROW HOUSTON TX Date 03/16/23 5 *198 2 5814
# 48211                                                                        Withdrawal Signature PHILLIPS 66 - U GAS LITTL HIGH RIDGE MO Date 02/27/23 ***80400 5541 %% Card 15 #3788
# 49181                                                                                                                        ELECTRONIC WITHDRAWAL WELLS FARGO CARDCCPYMT * Eff. Date:
# 219                                                                          Withdrawal #** WM SUPERCENTER #824 Wal-Mart Store ALBUQUERQUE ( NM Card 8468 Merchant Category Code: 5310
# 20339                                                                                                                  Card purchase LOWE'S #1151 5200 (2023-02-05) PORT ARTHUR TX 001
# 8549                                                                                    DBT PURCHASE ON 04/25 @ 22:08 CITY OF BALTIM CITY OF BALTIMORE 410-396-3971 MD CARD NBR: -8749
# 14294                                                                                                                         Point Of Sale Withdrawal JERRYS FOR ALL SEASDUNMORE PAUS
# 1699                                                                                 Withdrawal DEBIT CARD HOME* AHS.COM FRONTDOORHOME TN Date 01/27/23 ***89390 6300 %% Card 15 #8935
# 22363                                                                             ATM WTHDRWL ON 03/12 @ 19:32 4411 E. PACIFIC HIGHWAY 4411 E. PACIFIC HIGHWAY FIFE WA CARD NBR: -2510
# 5376                                                                                                                                   POS Withdrawal CHICK-FIL-A #02173 AVONDALE AZUS
# 38738                                                                                     Withdrawal OSSORIO BAKERY & CAFE COCOA FL Date 03/09/23 ** 5812 %% Card 25 #5481 %% MCC 5812
# 32358                                                                            Withdrawal MCSIGNATURE TRACFONE *AIRTIME TRACFONE.COM FL Date 07/19/22 ***43285 4814 %% Card 19 #1799
# 25976                                                                                                                       Withdrawal TOM THUMB #1784 MESQUITE TX %% Card 15 #0001 #*
# 40040                                                                                                                       Stash Your Cash Withdrawal Transferred to Acct#: xxxxx7800
# 40233                                         External Withdrawal SMARTPAY REWARDS 4INFO 877-403-2222 PREAUTHPMT CUMBERLAND F-4548 NORTH MAI FALL RIVER MA 6892 **5754CUMBERLAND F-454
# 18265                                                                                                                                       External Withdrawal CONSOLIDATEDCCU - CCCU
# 25349                                                                                                       DBT PURCHASE ON 03/09 @ 18:18 ALBERTSONS #3106 PUYALLUP WA CARD NBR: -6417
# 46691                                                                                                       Withdrawal #* MCDONALD'S F579 529 SW CUTOFF WORCESTER MA %% Card 15 #*6586
# 41136                                                                                                                                               Purchase TACO BELL * LAWRENCE KSUS
# 1760                                                                                                                                        WELLS FARGO AUTO ONLINE PMT CKF*388POS nan
# 43338                                                                                                                                              PHO 79 DAVIE FLUS : POS Transaction
# 31183                                                                     Withdrawal Debit Signature PANERA BREAD #* P 9480 DORCHESTER RD Date 02/05/23 9 *807 5 5814 %% Card 15 #4773
# 25936                                                                                          Withdrawal #* POS WM SUPERCENTER # Wal-Mart Super Cen EXCELSIOR SPR MO %% Card 15 #6601
# 16168                                                        Withdrawal DEBIT CARD Subway 16591 11425 S.Dupont Hwy Felton DE Date 02/03/22 1 *0396 4 5814 %% Card 15 #8847 %% MCC 5814
# 43354                                                                                                                                        POS Transaction DUNKIN #* AUSTINTOWN OHUS
# 12234                                                                                                                        Withdrawal Debit AMZN Mktp US*H29M881G1 Amzn.com/billWAUS
# 39202                                                                                POS PURCHASE ON 01/26 @ 17:13 WINCO FOODS #16 18301 Gem Heights Drive Puyallup WA CARD NBR: -5515
# 23061                                                                                              DEBIT CARD DEBIT 03-25-2023 FAMILY DOLLAR # 24549 HIGHWAY 1 PLAQUEMI Eff. Date: *00
# 9912                                                                                                                                      POS PURCHASE WHERE'S RUFUS SOCIAL C TYLER TX
# 39846                                                                                                                                         ACH Withdrawal SAMS CLUB MC - ONLINE PMT
# 33806                                                                       Withdrawal Debit Card AMZN Mktp US*JR6PL15V3 Amzn.com/bill WA Date 01/30/23 ***43287 5942 %% Card 15 #8849
# 10946                                                                                                                    Withdrawal Debit Card Withdrawal CHEDDARS **9 FAYETTEVILLE NC
# 33032                                                                                                        POS Withdrawal (FIP) Speedway 482 M Speedway 482 Main Leominster MA(9951)
# 15748                                                                       Withdrawal Home Banking Transfer To SMITH,MYRTIS *5015 Share 0030 SecureLink 02/10/2023 05:57 * - mortgage
# 37038                                                                                                   DEBIT CARD DEBIT ref #** auth #* 01-13-2022 WALMART.COM AA *6546 AR Eff. Date:
# 15393                                                                                                                                     External Withdrawal CAPITAL ONE - ONLINE PMT
# 11599                                                                                                                                            ELECTRONIC WITHDRAWAL VENMO PAYMENT *
# 26542                                                                                                                              Withdrawal Debit ZEL*JAMIL ESTRADA Visa Direct AZUS
# 27055                                                                                                                                                  Point Of Sale Withdrawal BILLIE
# 2260                                                                                                                                         #* SAVEWAY MARKET 1200 SHOUP ST SALMON ID
# 17288                                                                                                                                    Withdrawal Debit ARBYS 5423 WINTER SPRINGFLUS
# 19378                                                                                                                                 Point Of Sale Withdrawal AMAZON.COM SEATTLE WAUS
# 45771                                                                                                Withdrawal SHELL OIL *387 CRYSTAL SPRIN MS Date 01/04/23 * 5542 %% Card 35 #26704
# 15248                                                                                                                                DDA PUR CVS CarePa CVS CarePass 833-320-2273 RI *
# 2536                                                                                                                           DEBIT CARD DEBIT 03-24-2023 ICTICKETS 877-263-9372 ID *
# 22678                                                                                                        Withdrawal HAPPY DRAGON DECATUR GA Date 04/29/22 * 5812 %% Card 35 #60007
# 10063                                                                                                                            Point Of Sale Withdrawal Walmart.com Bentonville ARUS
# 872                                                                                                                  DEBIT CARD DEBIT auth #* 02-19-2023 APPLE.COM/BILL CUPERTINO CA *
# 13666                                                                                                   Withdrawal #* WM SUPERCENTER # Wal-Mart Super Cent TUCKER GA %% Card 35 #96663
# 37082                                                                                                                                 Point Of Sale Withdrawal HUFFS THOMPSONS STNTNUS
# 10472                                                                                                                Withdrawal #* MCDONALD'S F389 3535 BRIARWOOD BEND MONT BELVIEU TX
# 21749                                                                                                                                                  MAVERIK #459 PLEASANT GROV, nan
# 49683                                                                                                                                       ELECTRONIC WITHDRAWAL Connexus ExtrnlTfr *
# 3680                                                                                                                                        POS Transaction KLARNA INC KLARNA.COM OHUS
# 10875                                                                                                                                                Purchase QT 228 NORTH KANSAS MOUS
# 42367                                                                                  Withdrawal MasterCard DC TACO BELL 02572 8302 NORTH HWY 146 BAYTOWN Date 02/12/23 0 *979 5 5814
# 49202                                                                                                                                                Withdrawal %% TCode01 CD 9,000.00
# 47164                                                                                                                          Stash My Cash Withdrawal Transferred to Savings Account
# 21763                                                                                                                             Withdrawal Debit Audible*1U29Q80U1 Amzn.com/billNJUS
# 40565                                                                                                                           WITHDRAWAL POS 0310 1235 * AMAZON.COM*HG5EK SEATTLE WA
# 41331                                                                                                            Withdrawal #* FRESH FOODS #1 47 GREEN ST CLARKTON NC %% Card 15 #3025
# 36752                                                               Withdrawal Consumer Debit EDGEMERE MINI M 734 GRAFTON STREET WORCEST Date 02/02/23 0 *948 1 5499 %% Card 15 #*1301
# 33569                                                                            Withdrawal Signature base EB FOODIELAND NIGHT M *7200 CA Date 03/15/23 ***23228 7399 %% Card 25 #3424
# 39709                                                                                                                              POS Withdrawal HY-VEE LEE'S SUMMITLEE'S SUMMIT MOUS
# 2976                                                                                                                                  Withdrawal Debit ACTION CHURCH WWW.THEACTIONFLUS
# 49267                                                                                                                          Withdrawal Debit SP SOMETHING NEW BRI HTTPSSOMETHINIDUS
# 47474                                                                                                        DBT PURCHASE ON 03/24 @ 18:19 RED ROBIN NO 165 OLYMPIA WA CARD NBR: -4715
# 38294                                                                                  Withdrawal MasterCard DC STARBUCKS APTO AV CAP CARLOS LEON SN N MEX Date 02/14/23 3 *810 6 5814
# 9582                                                                                                                              Withdrawal Debit Card Withdrawal IHOP * HOLLYWOOD FL
# 11152                                                                                                                          DEBIT CARD DEBIT 03-09-2023 ALBERTSONS #0169 BOISE ID *
# 35809                                                                                                                                     Withdrawal Debit KISSME BEAUTY KISSMMEE FLUS
# 17541  Withdrawal TARGET DEBIT CRD Location - TARGET -2365 Queen Creek AZ / Terminal ID: 177 TYPE: ACH TRAN ID: *5170 DATA: 001 CO: TARGET DEBIT CRD %% ACH ECC POS %% ACH Trace **760
# 35141                                                                                                                                   ELECTRONIC WITHDRAWAL Acorns Invest Transfer *
# 41821                                                                                                                         ACH Withdrawal COMP NAME: AMANDA YODERS DESC: BILL PAYMT
# 44624                                                                      CGX BASE SAN JUAN SAN JUAN PR Withdrawal @ CGX BASE SAN JUAN SAN JUAN PR Trace #8659 (eff. date 12/12/2022)
# 43115                                                                                                                                  Withdrawal Debit WAL-MART #0705 MOUNT DORA FLUS
# 19261                                                                                     Withdrawal Debit Card PUBLIX #1746 PENSACOLA FL Date 11/05/22 ***30535 5411 %% Card 15 #5267
# 49868                                                                                                                                    Purchase THE ELMS HOTEL F&B EXCELSIOR SPRMOUS
# 13071                                                                                                                  DEBIT CARD DEBIT 02-24-2023 HONEY BEE TEA MANCHESTER MO auth #*
# 16170                                                                         Withdrawal DEBIT CARD Amazon.com*H27D54XO1 Amzn.com/bill WA Date 11/05/22 ***01130 5942 %% Card 15 #5803
# 3115                                                                                                   Withdrawal Debit Card LOS FAVORITOS 3 SCOTTSDALE AZ Date 01/25/23 ***75909 5812
# 2896                                                                      Withdrawal EXXONMOBIL TYPE: ONLINE PMT CO: EXXONMOBIL NAME: JODIE FUHRMANN %% ACH ECC WEB %% ACH Trace **034
# 41647                                                                                                                                       Withdrawal INTERNET TRANSFER TO : XXXX7809
# 26911                                                                                                          Point Of Sale Withdrawal WAL WAL-MART SUPER * 2065 WAL-SAMS KNOXVILLE (
# 25063                                                               Withdrawal Consumer Debit PRICE CHOPPER # 2 WORCESTER ROAD WEBSTER M Date 09/24/22 0 *946 3 5411 %% Card 15 #*7059
# 19663                                                                                                     Withdrawal TEXACO *7 LITHIA SPRING GA Date 01/16/23 * 5542 %% Card 35 #12231
# 37754                                                                                                                                    Withdrawal POS DOLLAR GENERAL # DG *228 STATE
# 35913                                                                                                                   DEBIT CARD DEBIT 02-02-2023 AMZN Mktp US*TK3 Amzn.com/billWA *
# 5612                                                                                                                                                     EPAY CHASE CREDIT CRD ID*9224
# 948                                                                                Withdrawal CONSUMER DEBIT CASH APP*RYAN HOLLI *4551 CA Date 11/30/22 ***65140 4829 %% Card 15 #5803
# 5974                                                                         Withdrawal Signature AMZN Mktp US*H87E65LX0 Amzn.com/bill WA Date 10/18/22 ***59990 5942 %% Card 15 #1219
# 11092                                                                                                                           DEBIT CARD DEBIT 07-31-2022 WINCO FOODS #11 Nampa ID *
# 49449                                                                                                                          DEBIT CARD DEBIT 03-21-2023 THE HOME DEPOT # EAGLE ID *
# 9866                                                                                                                    CKCD DEBIT 7790 11/26 19:33 LOWES #009 07* 866-483-7521 NC nan
# 17282                                                                                                                                    POS Transaction KLOVER APP BOOST Chicago ILUS
# 19766                                                                                                          Card purchase AMZN Mktp US*HC5YR4130 5942 (2023-03-15) Amzn.com/bill WA
# 35395                                                                                                                            Card purchase Google King 5734 (2022-04-27) 650-*0 CA
# 32572                                                                                Withdrawal PFCU CHECK CARD ULTA 1390 PHILADELPHIA PA Date 02/24/23 ***01021 5977 %% Card 25 #6397
# 37210                                                                                                                                 Withdrawal POS KAAS ENTERPRISES LLC 1017 4TH AVE
# 1997                                                                                                                           Stash My Cash Withdrawal Transferred to Savings Account
# 17318                                                                                                             DEBIT CARD DEBIT 01-17-2023 CASH APP*MARLO WILL *4551 CA auth #84005
# 40281                                                                                                             DEBIT CARD DEBIT 03-29-2023 DPHC SSM HEALTH PHA BRIDGETON MO auth #*
# 8337                                                                                       Withdrawal Earnin Active TYPE: PAYMENTRET ID: *4784 CO: Earnin Active NAME: Rosemarie Diego
# 39611                                                   Withdrawal DEBIT CARD DD DOORDASH BURGERKIN 855-973-1040 CA Date 03/06/23 ***82423 5812 Card 1490 Merchant Category Code: 5812
# 31932                                                                                                              Withdrawal #* LOWE'S #500 115 WAGNER RD. MONACA PA %% Card 19 #0828
# 8954                                                                                                        Withdrawal Debit Card Subway 14005 Glendale AZ Date 04/06/22 ***15854 5814
# 34114                                                                                                                                                             RETURNED NSF FEE nan
# 20690                                                                                                                          POS Transaction GOOGLE *Playrix Games 855-836-3987 CAUS
# 33623                                                                                                                                Withdrawal Debit APPLE.COM/BILL 866-712-7753 CAUS
# 41874                                                                                                                                      External Withdrawal CHASE CREDIT CRD - EPAY
# 32747                                                                                                                            Point Of Sale Withdrawal SAFEWAY #1704 VANCOUVER WAUS
# 24567                                                                                                                                    External Withdrawal EASTERSEALSREHAB PURCHASE
# 39235                                                                                             DEBIT CARD DEBIT 03-11-2023 DENNY S #7037 1579 FRY ROAD KATY TX auth #* Eff. Date: *
# 38625                                                                                                         DBT PURCHASE ON 12/18 @ 17:19 UBER TRIP HELP.UBER.COM CA CARD NBR: -0213
# 7575                                                                          Withdrawal CAPITAL ONE TYPE: MOBILE PMT ID: *4380 CO: CAPITAL ONE NAME: ROGER W JACKS %% ACH Trace **004
# 27257                                                                                                                               DDA PUR GFS STORE GFS STORE 2700 Cass Elkhart IN *
# 6460                                                                                                                                      DDA PUR DOLLAR GE DOLLAR GE DG * CULVER IN *
# 16883                                                                                                                                         Withdrawal Debit SUSHI LOLA ORLANDO FLUS
# 43454                                                                                                                      Point Of Sale Withdrawal DOLLAR GENERAL #13643 HENDERSON KY
# 40060                                                                                                                                      Withdrawal Home Banking Transfer To GRUELLE
# 40082                                                                                                               Withdrawal #** DOLLAR GE DG *130 CUMBERLAND FU TN %% Card 18 #7096
# 23218                                                                                         Withdrawal DEBIT CARD JIMMY JOHNS - 787 - EC 815-838-7827 IL Date 02/27/23 ***00820 5814
# 37166                                                                               Withdrawal MCSIGNATURE ARNIS BROWNSBURG BROWNSBURG IN Date 05/25/22 ***44988 5812 %% Card 19 #1140
# 40599                                                                                                                                 DEBIT CARD DEBIT auth #* 09-24-2022 LITTLE PEACH
# 16827                                                                                                                                                          MISCELLANEOUS DEBIT nan
# 42694                                                                                                                  DBT PURCHASE ON 00/00 @ 00:00 LOCATION + ATM HST NOT AV AILABLE
# 3156                                                                                                                                                           *9699 HONDA PMT IDA*715
# 12069                                                                                                           Point Of Sale Withdrawal WAL WAL-MART SUPER * 1263 WAL-SAMS EVANSVILLE
# 33596                                                                                                           DEBIT CARD DEBIT auth #* 04-06-2022 FSI*ALABAMA POWE 877-677-2661 GA *
# 36312                                                                         Withdrawal MCSIGNATURE DAVE'S HOMETOWN SHOP ELLWOOD CITY PA Date 08/17/22 ***14041 5411 %% Card 19 #3759
# 35158                                                                                                                         DBT CRD 2235 09/12/22 *24 VIVINT INC/US 800-216-5232UT 0
# 4211                                                                                  Withdrawal CONSUMER DEBIT EXXONMOBIL *74 RED OAK TX Date 11/11/22 ***45420 5542 %% Card 15 #4499
# 27070                                                                                                                                         POS Withdrawal TOMS LIQUOR FOUNTAIN COUS
# 43635                                                                                                                      CKCD DEBIT 1965 08/12 09:56 FRANCESCA' S B146 DURHAM NC nan
# 2014                                                                                                                             EXXONMOBIL 97563 PEMBROKE PINE FLUS : POS Transaction
# 41288                                                                                                                                  POS PURCHASE/PIN * SHEETZ 0550 JOHNSTOWN PA nan
# 10794                                                                                                                                         Withdrawal Internet Transfer to *436 SAV
# 38241                                                                                                                         CKCD DEBIT 0363 12/21 04:29 DUNHAMS 22 1 DANVILLE OH nan
# 42287                                                                                      Withdrawal Debit Card WING ZONE 216 JACKSONVILL JACKSONVILLE NC Date 10/14/22 ***40490 5812
# 31512                                                                                                                   Point Of Sale Withdrawal AMZN Mktp US*324Q35Amzn.com/bill WAUS
# 40678                                                                                                     Point Of Sale Withdrawal Pinned WAL-MART #2118 Wal-Mart Store LUNENBURG MAUS
# 11525                                                                                                                  DEBIT CARD DEBIT auth #* 03-05-2023 FOOD LION #1547 EDGEWOOD MD
# 2546                                                                                                                                      Withdrawal Debit MCW#277-DELTONA 866-*9 FLUS
# 9668                                                                                                                            Transfer to *-07S Internet Transfer 03/23/2023 19:53 *
# 28879                                                                                                                                  Purchase STATE FARM INSURANCE 800-956-6310 ILUS
# 5227                                                                                                              DEBIT CARD DEBIT 03-22-2023 CHILI'S HAMMOND HAMMOND LA Eff. Date: **
# 10768                                                                                                               DEBIT CARD DEBIT 11-14-2022 MCDONALD S F2050 FLORISSANT MO auth #*
# 30149                                                                                                           Withdrawal WAWA 203 10 BOOT ROAD WEST CHESTER PA %% Card 25 #8279 #*00
# 36563                                                                                                                           Withdrawal Debit COUNTRY HARVEST APP VALLEY FALLS KSUS
# 33342                                                                                                                                 POS PURCHASE * PRIME SIRLOIN DUNCANSVILLE PA nan
# 23128                                                                                                                          Change It Up Debit Withdrawal Transferred to Acct#: *70
# 22681                                                                                              Withdrawal #* DOLLAR GENERAL DG *154 MAIN EAST EARL PA %% Card 15 #6821 %% MCC 5310
# 9720                                                                                                COMENITY PAY OH ID: *0275 CO: COMENITY PAY OH NAME: RHEANON KULCHAK %% ACH ECC WEB
# 5186                                                                                   Withdrawal MasterCard DC WWW.GCCISD.NET 4544 East Freeway BAYTOWN T Date 02/14/23 0 *517 2 8211
# 18127                                        Withdrawal NFCU ACH TYPE: PAYMENT ID: *0027 DATA: CREDIT CARD-ONE TIME CO: NFCU ACH NAME: JAROD HARAKAL %% ACH ECC WEB %% ACH Trace **635
# 27271                                                                                                                                                                   Withdrawal nan
# 25842                                                                                                                               XX1817 POS PURCHASE AT POP SHOP MARSHALLMO *73 * 0
# 7386                                                                                                                                        Withdrawal Debit VENDING FORT LAUDERDAFLUS
# 32926                                                                                                                          Change It Up Debit Withdrawal Transferred to Acct#: *25
# 49033                                                                                                                                              Withdrawal #* AMAZON.COM SEATTLE WA
# 45763                                                                                                                                                         Overdraft/NSF Charge nan
# 8025                                                                                                Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: CYNTHIA WILLIAMS
# 49607                                                                                                                                        Withdrawal Home Banking Transfer To HOPPS
# 5252                                                                                                                                               INET XFER 03-10 TO XXXXXXXX3175 nan
# 4295                                                                                                  Withdrawal TRAVELERS TYPE: PER INSUR ID: *7005 CO: TRAVELERS NAME: JOHNSONJOSEPH
# 40725                                                                                                                             DEBIT CARD DEBIT 03-14-2023 QT 642 FENTON MO auth #*
# 34141                                                                                                                    DEBIT CARD DEBIT 03-26-2023 PARIS ACE OCEAN OCEAN SPRINGSMS *
# 31142                                                         Withdrawal CAPITAL ONE TYPE: MOBILE PMT ID: *4380 CO: CAPITAL ONE NAME: ALESIA SANCHEZ %% ACH ECC WEB %% ACH Trace **341
# 21353                                                                                 Withdrawal MasterCard DC DicksSportingGo 345 Court Street Coraopoli Date 01/23/23 2 *8713 2 5941
# 41894                                                                                               POS PURCHASE ON 02/16 @ 21:23 AMAZON.COM*HP7 AMAZON.COM SEATTLE WA CARD NBR: -5604
# 17128                                                                                                                                           POS Withdrawal AMAZON.COM SEATTLE WAUS
# 35398                                                                                                                                                      AC-ALLY BANK -$TRANSFER nan
# 45274                                                                                                                         POS Transaction CASEYS #1708 400 W NORRIS DR OTTAWA ILUS
# 39199                                                                                                                     Withdrawal #** TJ MAXX #049 2660 W CHANDLER BLVD CHANDLER AZ
# 48828                                                                                                                   Point Of Sale Withdrawal AFFIRM PAY LAE1PROT SAN FRANCISCOCAUS
# 49392                                                               Withdrawal COMMWLTHOFPAPATH TYPE: PAINDIVLTX ID: *3133 CO: COMMWLTHOFPAPATH NAME: JOHANA CASTRO %% ACH Trace **031
# 33512                                                               Withdrawal PAYPAL TYPE: INST XFER ID: PAYPALSI77 CO: PAYPAL NAME: HEAVEN FEASTER %% ACH ECC WEB %% ACH Trace **804
# 21850                                                                                                               POS Withdrawal (FIS) www.cvs.com www.cvs.com 800-746-7287 RI(4623)
# 28415                                                                                                Withdrawal Home Banking Transfer Online Banking Withdrawal Transfer To Share 0002
# 28290                                                                                                                      DEBIT CARD DEBIT auth #* 03-27-2023 STOKOS TOWSON TOWSON MD
# 21376                                                                                                                                                                    SALES TAX nan
# 11220                                                                     Withdrawal CONSUMER DEBIT SONIC DRIVE IN #3488 HOPKINSVILLE KY Date 12/28/22 0 *6572 1 5814 %% Card 18 #5443
# 27580                                                                                                                                                    Purchase THE DOCK TOPEKA KSUS
# 12928                                                                                                                      POS Transaction WAL-MART #0852 4041 VETERANS RD OTTAWA ILUS
# 8021                                                                                                                                     POS Transaction MOE'S SMOKE SHOP ANSONIA CTUS
# 27150                                                                                                                                       Withdrawal Internet Transfer TO : XXXX1582
# 5547                                                                                                                          PURCHASE auth #* 11-18-2022 EMF*K-LOVE 800-525-5683 CA *
# 31070                                                                                                  DBT PURCHASE ON 01/26 @ 17:22 LYFT RIDE WED 3PM 855-865-9553 CA CARD NBR: -2241
# 2885                                                                                                                    WTHDRL CHK 2791 01/31 07:55 BENCHMARK COM 90 SOUTH HILL VA nan
# 48550                                                                                      DEBIT CARD DEBIT auth #* 02-28-2023 MCDONALD S F11291 EVANSVILLE IN Eff. Date: 03-01-2023 *
# 39546                                                                                                    DBT PURCHASE ON 01/15 @ 17:19 SHELL SERVICE STATION TACOMA WA CARD NBR: -3617
# 41171                                                                                Withdrawal CONSUMER DEBIT TACO BELL *4 FLORISSANT MO Date 11/28/22 ***36850 5814 %% Card 15 #0996
# 32497                                                                                                                                       Withdrawal Debit LOWE'S #2364 DELTONA FLUS
# 27461                                                                                                       CHECK/DEBIT VSA PUR GIFTSHOPHYATTREGENCYORL ORLANDO FL (03/10/23 19:49:44)
# 39515                                                                                   Withdrawal PFCU Check Card KFC K* PHILADELPHIA PA Date 02/02/23 ***00758 5814 %% Card 30 #1285
# 2854                                                                                                                                         Withdrawal Debit NITRADO NET KARLSRUHE DE
# 37312                                                                                                Bill payment Card purchase AT&T *PAYMENT 4899 (2023-03-03) 800-288-2020 FL IN7900
# 8976                                                                                                                                     External Withdrawal CAPITAL ONE =- ONLINE PMT
#
#                    merchant_name                    PREDICTIONS
# 49919                  STARBUCKS                      STARBUCKS
# 49367                    WALMART                        WALMART
# 20202            Unknow Merchant                Unknow Merchant
# 48211                PHILLIPS 66                    PHILLIPS 66
# 49181                WELLS FARGO                    WELLS FARGO
# 219                      WALMART                        WALMART
# 20339                     LOWE'S                         LOWE'S
# 8549             Unknow Merchant                Unknow Merchant
# 14294            Unknow Merchant                Unknow Merchant
# 1699             Unknow Merchant                Unknow Merchant
# 22363            Unknow Merchant                Unknow Merchant
# 5376                 CHICK-FIL-A                    CHICK-FIL-A
# 38738            Unknow Merchant                Unknow Merchant
# 32358            Unknow Merchant                Unknow Merchant
# 25976                  TOM THUMB                Unknow Merchant
# 40040            Unknow Merchant                Unknow Merchant
# 40233           CUMBERLAND FARMS               CUMBERLAND FARMS
# 18265            Unknow Merchant                Unknow Merchant
# 25349                 ALBERTSONS                     ALBERTSONS
# 46691                 MCDONALD'S                     MCDONALD'S
# 41136                  TACO BELL                      TACO BELL
# 1760                 WELLS FARGO                    WELLS FARGO
# 43338            Unknow Merchant                Unknow Merchant
# 31183               PANERA BREAD                   PANERA BREAD
# 25936                    WALMART                        WALMART
# 16168                     SUBWAY                         SUBWAY
# 43354             DUNKIN' DONUTS                 DUNKIN' DONUTS
# 12234                 AMAZON.COM                     AMAZON.COM
# 39202                      WINCO                          WINCO
# 23061              FAMILY DOLLAR                  FAMILY DOLLAR
# 9912             Unknow Merchant                Unknow Merchant
# 39846                 SAM'S CLUB                     SAM'S CLUB
# 33806                 AMAZON.COM                     AMAZON.COM
# 10946  CHEDDAR'S SCRATCH KITCHEN                Unknow Merchant
# 33032                   SPEEDWAY                       SPEEDWAY
# 15748            Unknow Merchant                Unknow Merchant
# 37038                    WALMART                        WALMART
# 15393            Unknow Merchant                Unknow Merchant
# 11599            Unknow Merchant                Unknow Merchant
# 26542            Unknow Merchant                Unknow Merchant
# 27055            Unknow Merchant                Unknow Merchant
# 2260                     SALOMON                        SALOMON
# 17288                     ARBY'S                         ARBY'S
# 19378                 AMAZON.COM                     AMAZON.COM
# 45771                  SHELL OIL                      SHELL OIL
# 15248                 CVS HEALTH                     CVS HEALTH
# 2536             Unknow Merchant                Unknow Merchant
# 22678            Unknow Merchant                Unknow Merchant
# 10063                    WALMART                        WALMART
# 872                  APPLE STORE                    APPLE STORE
# 13666                    WALMART                        WALMART
# 37082            Unknow Merchant                Unknow Merchant
# 10472                 MCDONALD'S                     MCDONALD'S
# 21749            Unknow Merchant                Unknow Merchant
# 49683            Unknow Merchant                Unknow Merchant
# 3680             Unknow Merchant                Unknow Merchant
# 10875                     QT GAS                         QT GAS
# 42367                  TACO BELL                      TACO BELL
# 49202            Unknow Merchant                Unknow Merchant
# 47164            Unknow Merchant                Unknow Merchant
# 21763                 AMAZON.COM                     AMAZON.COM
# 40565                 AMAZON.COM                     AMAZON.COM
# 41331            Unknow Merchant                Unknow Merchant
# 36752            Unknow Merchant                Unknow Merchant
# 33569            Unknow Merchant                Unknow Merchant
# 39709               HY-VEE-FOODS                   HY-VEE-FOODS
# 2976             Unknow Merchant                Unknow Merchant
# 49267            Unknow Merchant                Unknow Merchant
# 47474      RED ROBIN RESTAURANTS                Unknow Merchant
# 38294                  STARBUCKS                Unknow Merchant
# 9582                        IHOP                Unknow Merchant
# 11152                 ALBERTSONS                     ALBERTSONS
# 35809            Unknow Merchant                Unknow Merchant
# 17541                     TARGET                         TARGET
# 35141            Unknow Merchant                Unknow Merchant
# 41821            Unknow Merchant                Unknow Merchant
# 44624            Unknow Merchant                Unknow Merchant
# 43115                    WALMART                        WALMART
# 19261       PUBLIX SUPER MARKETS           PUBLIX SUPER MARKETS
# 49868            Unknow Merchant                Unknow Merchant
# 13071            Unknow Merchant                Unknow Merchant
# 16170                 AMAZON.COM                     AMAZON.COM
# 3115             Unknow Merchant                Unknow Merchant
# 2896                 EXXON MOBIL                    EXXON MOBIL
# 41647            Unknow Merchant                Unknow Merchant
# 26911                    WALMART                        WALMART
# 25063              PRICE CHOPPER                  PRICE CHOPPER
# 19663                     TEXACO                         TEXACO
# 37754             DOLLAR GENERAL                 DOLLAR GENERAL
# 35913                 AMAZON.COM                     AMAZON.COM
# 5612             Unknow Merchant                Unknow Merchant
# 948              Unknow Merchant                Unknow Merchant
# 5974                  AMAZON.COM                     AMAZON.COM
# 11092                      WINCO                          WINCO
# 49449                 HOME DEPOT                     HOME DEPOT
# 9866                      LOWE'S                         LOWE'S
# 17282            Unknow Merchant                Unknow Merchant
# 19766                 AMAZON.COM                     AMAZON.COM
# 35395                     GOOGLE                         GOOGLE
# 32572                       ULTA                           ULTA
# 37210            Unknow Merchant                Unknow Merchant
# 1997             Unknow Merchant                Unknow Merchant
# 17318            Unknow Merchant                Unknow Merchant
# 40281            Unknow Merchant                Unknow Merchant
# 8337             Unknow Merchant                Unknow Merchant
# 39611            Unknow Merchant                Unknow Merchant
# 31932                     LOWE'S                         LOWE'S
# 8954                      SUBWAY                         SUBWAY
# 34114            Unknow Merchant                Unknow Merchant
# 20690                     GOOGLE                         GOOGLE
# 33623                APPLE STORE                    APPLE STORE
# 41874            Unknow Merchant                Unknow Merchant
# 32747                    SAFEWAY                        SAFEWAY
# 24567            Unknow Merchant                Unknow Merchant
# 39235            Unknow Merchant                Unknow Merchant
# 38625                       UBER                           UBER
# 7575             Unknow Merchant                Unknow Merchant
# 27257            Unknow Merchant                Unknow Merchant
# 6460              DOLLAR GENERAL                 DOLLAR GENERAL
# 16883            Unknow Merchant                Unknow Merchant
# 43454             DOLLAR GENERAL                 DOLLAR GENERAL
# 40060            Unknow Merchant                Unknow Merchant
# 40082           CUMBERLAND FARMS                 DOLLAR GENERAL
# 23218               JIMMY JOHN'S                   JIMMY JOHN'S
# 37166            Unknow Merchant                Unknow Merchant
# 40599            Unknow Merchant                Unknow Merchant
# 16827            Unknow Merchant                Unknow Merchant
# 42694            Unknow Merchant                Unknow Merchant
# 3156                       HONDA                Unknow Merchant
# 12069                    WALMART                        WALMART
# 33596            Unknow Merchant                Unknow Merchant
# 36312            Unknow Merchant                Unknow Merchant
# 35158                     VIVINT                         VIVINT
# 4211                 EXXON MOBIL                    EXXON MOBIL
# 27070            Unknow Merchant                Unknow Merchant
# 43635            Unknow Merchant                Unknow Merchant
# 2014                 EXXON MOBIL                    EXXON MOBIL
# 41288                     SHEETZ                         SHEETZ
# 10794            Unknow Merchant                Unknow Merchant
# 38241            Unknow Merchant                Unknow Merchant
# 42287            Unknow Merchant                Unknow Merchant
# 31512                 AMAZON.COM                     AMAZON.COM
# 40678                    WALMART                        WALMART
# 11525                  FOOD LION                      FOOD LION
# 2546             Unknow Merchant                Unknow Merchant
# 9668             Unknow Merchant                Unknow Merchant
# 28879       STATE FARM INSURANCE           STATE FARM INSURANCE
# 5227         CHILI'S GRILL & BAR                Unknow Merchant
# 10768            Unknow Merchant                     MCDONALD'S
# 30149                       WAWA                           WAWA
# 36563            Unknow Merchant                Unknow Merchant
# 33342            Unknow Merchant                   AMAZON PRIME
# 23128            Unknow Merchant                Unknow Merchant
# 22681             DOLLAR GENERAL                 DOLLAR GENERAL
# 9720             Unknow Merchant                Unknow Merchant
# 5186             Unknow Merchant                Unknow Merchant
# 18127            Unknow Merchant                Unknow Merchant
# 27271            Unknow Merchant                Unknow Merchant
# 25842            Unknow Merchant                    STOP & SHOP
# 7386             Unknow Merchant                Unknow Merchant
# 32926            Unknow Merchant                Unknow Merchant
# 49033                 AMAZON.COM                     AMAZON.COM
# 45763            Unknow Merchant                Unknow Merchant
# 8025             Unknow Merchant                Unknow Merchant
# 49607            Unknow Merchant                Unknow Merchant
# 5252             Unknow Merchant                Unknow Merchant
# 4295                    TRAVELER                       TRAVELER
# 40725                     QT GAS                         QT GAS
# 34141               ACE HARDWARE                   ACE HARDWARE
# 31142            Unknow Merchant                Unknow Merchant
# 21353            Unknow Merchant                Unknow Merchant
# 41894                 AMAZON.COM                     AMAZON.COM
# 17128                 AMAZON.COM                     AMAZON.COM
# 35398            Unknow Merchant                Unknow Merchant
# 45274     CASEY'S GENERAL STORES         CASEY'S GENERAL STORES
# 39199                    TJ MAXX                        TJ MAXX
# 48828            Unknow Merchant                Unknow Merchant
# 49392            Unknow Merchant                Unknow Merchant
# 33512            Unknow Merchant                Unknow Merchant
# 21850                 CVS HEALTH                     CVS HEALTH
# 28415            Unknow Merchant                Unknow Merchant
# 28290            Unknow Merchant                Unknow Merchant
# 21376            Unknow Merchant                Unknow Merchant
# 11220             SONIC DRIVE-IN                 SONIC DRIVE-IN
# 27580            Unknow Merchant                Unknow Merchant
# 12928                    WALMART                        WALMART
# 8021       MOE'S SOUTHWEST GRILL                Unknow Merchant
# 27150            Unknow Merchant                Unknow Merchant
# 5547             Unknow Merchant  LOVES TRAVEL & COUNTRY STORES
# 31070                       LYFT                           LYFT
# 2885             Unknow Merchant                Unknow Merchant
# 48550            Unknow Merchant                Unknow Merchant
# 39546                  SHELL OIL                      SHELL OIL
# 41171                  TACO BELL                      TACO BELL
# 32497                     LOWE'S                         LOWE'S
# 27461            Unknow Merchant                Unknow Merchant
# 39515                        KFC                            KFC
# 2854             Unknow Merchant                Unknow Merchant
# 37312                       AT&T                           AT&T
# 8976             Unknow Merchant                Unknow Merchant

# %%
# from sklearn.linear_model import SGDClassifier

# classifier = Pipeline([
#     ('vectorizer', TfidfVectorizer(stop_words=stopwords.words('english') + list(string.punctuation))),
#     ('scaler', StandardScaler(with_mean=False)),
#     ('classifier', SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=1000, tol=1e-3)),
# ])

# train(classifier, df_known_class_pred['TRANSACTION_DETAILS'], df_known_class_pred['AFS_MECHANT_NAMES'])

# %% [markdown]
# - K-Nearest Neighbors

# %%
# from sklearn.neighbors import KNeighborsClassifier

# classifier4 = Pipeline([('vectorizer', TfidfVectorizer(stop_words=stopwords.words('english') + list(string.punctuation))),
#                         ('classifier', KNeighborsClassifier(n_neighbors=5))])

# train(classifier4, df_known_class_pred['TRANSACTION_DETAILS'], df_known_class_pred['AFS_MECHANT_NAMES'])

# KNN = cls_acc
# Ktime = cls_time
# print("\n\nKNN: ", KNN)
# print("Time: ", Ktime)
